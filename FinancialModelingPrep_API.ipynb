# %% [markdown]
# # IMPACT OF QUARTERLY EARNINGS REPORTS ON THE STOCK PRICE OF APPLE
# ## Project Overview:
# *   A financial news publication wants to create a new content section featuring data-driven articles on market reactions to Apples news. The goal is to show a quantifiable relationship between the press release abour earnings event and market performance.
# ### Database
# *   The datasets are fetched from the Finanicial Modeling Prep API

# %%
# The necessary datasets: daily stock price (historical-price-eod), earnings (earnings)

#  from FMP API
base_url = "https://financialmodelingprep.com"
data_type = "historical-price-eod/full"
data_type_2 = "earnings"
ticker = "AAPL"
API_KEY = "GAn9VR6Q3RirhmpxrjMhQnmKjYUDkXFu"

url_stock = f"{base_url}/stable/{data_type}?symbol={ticker}&apikey={API_KEY}"
url_earnings = f"{base_url}/stable/{data_type_2}?symbol={ticker}&apikey={API_KEY}"

# %%
import requests
import pandas as pd

# %%
response = requests.get(url_stock)
response_2 = requests.get(url_earnings)

stock_data = response.json()
earnings_data = response_2.json()

# %%
stock_data
# Out:
# [{'symbol': 'AAPL',
#   'date': '2025-10-02',
#   'open': 256.575,
#   'high': 257.67,
#   'low': 254.15,
#   'close': 257.365,
#   'volume': 17488796,
#   'change': 0.79,
#   'changePercent': 0.30790217,
#   'vwap': 256.4},
#  {'symbol': 'AAPL',
#   'date': '2025-10-01',
#   'open': 255.04,
#   'high': 258.79,
#   'low': 254.93,
#   'close': 255.45,
#   'volume': 48713940,
#   'change': 0.41,
#   'changePercent': 0.16076,
#   'vwap': 256.0525},
#  {'symbol': 'AAPL',
#   'date': '2025-09-30',
#   'open': 254.86,
#   'high': 255.92,
#   'low': 253.11,
#   'close': 254.63,
#   'volume': 37704300,
#   'change': -0.225,
#   'changePercent': -0.09024563,
#   'vwap': 254.63},
#  {'symbol': 'AAPL',
#   'date': '2025-09-29',
#   'open': 254.56,
#   'high': 255,
#   'low': 253.01,
#   'close': 254.43,
#   'volume': 40127700,
#   'change': -0.13,
#   'changePercent': -0.05106851,
#   'vwap': 254.25},
#  {'symbol': 'AAPL',
#   'date': '2025-09-26',
#   'open': 254.1,
#   'high': 257.6,
#   'low': 253.78,
#   'close': 255.46,
#   'volume': 46076300,
#   'change': 1.37,
#   'changePercent': 0.53522,
#   'vwap': 255.235},
#  {'symbol': 'AAPL',
#   'date': '2025-09-25',
#   'open': 253.21,
#   'high': 257.17,
#   'low': 251.71,
#   'close': 256.87,
#   'volume': 55202100,
#   'change': 3.66,
#   'changePercent': 1.45,
#   'vwap': 254.74},
#  {'symbol': 'AAPL',
#   'date': '2025-09-24',
#   'open': 255.22,
#   'high': 255.74,
#   'low': 251.04,
#   'close': 252.31,
#   'volume': 42303710,
#   'change': -2.91,
#   'changePercent': -1.14,
#   'vwap': 253.5775},
#  {'symbol': 'AAPL',
#   'date': '2025-09-23',
#   'open': 255.88,
#   'high': 257.34,
#   'low': 253.58,
#   'close': 254.43,
#   'volume': 60275200,
#   'change': -1.44,
#   'changePercent': -0.56667,
#   'vwap': 255.3075},
#  {'symbol': 'AAPL',
#   'date': '2025-09-22',
#   'open': 248.3,
#   'high': 256.64,
#   'low': 248.12,
#   'close': 256.08,
#   'volume': 105517416,
#   'change': 7.78,
#   'changePercent': 3.13,
#   'vwap': 252.285},
#  {'symbol': 'AAPL',
#   'date': '2025-09-19',
#   'open': 241.23,
#   'high': 246.3,
#   'low': 240.21,
#   'close': 245.5,
#   'volume': 163741314,
#   'change': 4.28,
#   'changePercent': 1.77,
#   'vwap': 243.31},
#  {'symbol': 'AAPL',
#   'date': '2025-09-18',
#   'open': 239.97,
#   'high': 241.2,
#   'low': 236.65,
#   'close': 237.88,
#   'volume': 44249600,
#   'change': -2.09,
#   'changePercent': -0.87094,
#   'vwap': 238.925},
#  {'symbol': 'AAPL',
#   'date': '2025-09-17',
#   'open': 238.97,
#   'high': 240.1,
#   'low': 237.73,
#   'close': 238.99,
#   'volume': 46508017,
#   'change': 0.02,
#   'changePercent': 0.00836925,
#   'vwap': 238.9475},
#  {'symbol': 'AAPL',
#   'date': '2025-09-16',
#   'open': 237.18,
#   'high': 241.22,
#   'low': 236.32,
#   'close': 238.15,
#   'volume': 63421100,
#   'change': 0.975,
#   'changePercent': 0.40897,
#   'vwap': 238.2175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-15',
#   'open': 237,
#   'high': 238.19,
#   'low': 235.03,
#   'close': 236.7,
#   'volume': 42699524,
#   'change': -0.3,
#   'changePercent': -0.12658,
#   'vwap': 236.73},
#  {'symbol': 'AAPL',
#   'date': '2025-09-12',
#   'open': 229.22,
#   'high': 234.51,
#   'low': 229.02,
#   'close': 234.07,
#   'volume': 55824216,
#   'change': 4.85,
#   'changePercent': 2.12,
#   'vwap': 231.705},
#  {'symbol': 'AAPL',
#   'date': '2025-09-11',
#   'open': 226.88,
#   'high': 230.45,
#   'low': 226.65,
#   'close': 230.03,
#   'volume': 50208600,
#   'change': 3.16,
#   'changePercent': 1.39,
#   'vwap': 228.5025},
#  {'symbol': 'AAPL',
#   'date': '2025-09-10',
#   'open': 232.19,
#   'high': 232.42,
#   'low': 225.95,
#   'close': 226.79,
#   'volume': 83440810,
#   'change': -5.4,
#   'changePercent': -2.33,
#   'vwap': 229.3375},
#  {'symbol': 'AAPL',
#   'date': '2025-09-09',
#   'open': 237,
#   'high': 238.78,
#   'low': 233.36,
#   'close': 234.35,
#   'volume': 66313918,
#   'change': -2.65,
#   'changePercent': -1.12,
#   'vwap': 235.8725},
#  {'symbol': 'AAPL',
#   'date': '2025-09-08',
#   'open': 239.3,
#   'high': 240.15,
#   'low': 236.34,
#   'close': 237.88,
#   'volume': 48999500,
#   'change': -1.42,
#   'changePercent': -0.5934,
#   'vwap': 238.4175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-05',
#   'open': 240,
#   'high': 241.32,
#   'low': 238.49,
#   'close': 239.69,
#   'volume': 54870400,
#   'change': -0.305,
#   'changePercent': -0.12917,
#   'vwap': 239.875},
#  {'symbol': 'AAPL',
#   'date': '2025-09-04',
#   'open': 238.45,
#   'high': 239.9,
#   'low': 236.74,
#   'close': 239.78,
#   'volume': 47549429,
#   'change': 1.33,
#   'changePercent': 0.55777,
#   'vwap': 238.7175},
#  {'symbol': 'AAPL',
#   'date': '2025-09-03',
#   'open': 237.21,
#   'high': 238.85,
#   'low': 234.36,
#   'close': 238.47,
#   'volume': 66427835,
#   'change': 1.26,
#   'changePercent': 0.53117,
#   'vwap': 237.2225},
#  {'symbol': 'AAPL',
#   'date': '2025-09-02',
#   'open': 229.25,
#   'high': 230.85,
#   'low': 226.97,
#   'close': 229.72,
#   'volume': 44075638,
#   'change': 0.47,
#   'changePercent': 0.20502,
#   'vwap': 229.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-08-29',
#   'open': 232.51,
#   'high': 233.38,
#   'low': 231.37,
#   'close': 232.14,
#   'volume': 39418437,
#   'change': -0.37,
#   'changePercent': -0.15913,
#   'vwap': 232.35},
#  {'symbol': 'AAPL',
#   'date': '2025-08-28',
#   'open': 230.82,
#   'high': 233.41,
#   'low': 229.34,
#   'close': 232.56,
#   'volume': 38074700,
#   'change': 1.74,
#   'changePercent': 0.75383,
#   'vwap': 231.5325},
#  {'symbol': 'AAPL',
#   'date': '2025-08-27',
#   'open': 228.61,
#   'high': 230.9,
#   'low': 228.26,
#   'close': 230.49,
#   'volume': 31259513,
#   'change': 1.88,
#   'changePercent': 0.82236,
#   'vwap': 229.565},
#  {'symbol': 'AAPL',
#   'date': '2025-08-26',
#   'open': 226.87,
#   'high': 229.49,
#   'low': 224.69,
#   'close': 229.31,
#   'volume': 54575107,
#   'change': 2.44,
#   'changePercent': 1.08,
#   'vwap': 227.59},
#  {'symbol': 'AAPL',
#   'date': '2025-08-25',
#   'open': 226.48,
#   'high': 229.3,
#   'low': 226.23,
#   'close': 227.16,
#   'volume': 30983133,
#   'change': 0.68,
#   'changePercent': 0.30025,
#   'vwap': 227.2925},
#  {'symbol': 'AAPL',
#   'date': '2025-08-22',
#   'open': 226.17,
#   'high': 229.09,
#   'low': 225.41,
#   'close': 227.76,
#   'volume': 42477811,
#   'change': 1.59,
#   'changePercent': 0.70301,
#   'vwap': 227.1075},
#  {'symbol': 'AAPL',
#   'date': '2025-08-21',
#   'open': 226.27,
#   'high': 226.52,
#   'low': 223.78,
#   'close': 224.9,
#   'volume': 30621249,
#   'change': -1.37,
#   'changePercent': -0.60547,
#   'vwap': 225.3675},
#  {'symbol': 'AAPL',
#   'date': '2025-08-20',
#   'open': 229.98,
#   'high': 230.47,
#   'low': 225.77,
#   'close': 226.01,
#   'volume': 42263900,
#   'change': -3.97,
#   'changePercent': -1.73,
#   'vwap': 228.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-08-19',
#   'open': 231.28,
#   'high': 232.87,
#   'low': 229.35,
#   'close': 230.56,
#   'volume': 39402600,
#   'change': -0.715,
#   'changePercent': -0.31131,
#   'vwap': 231.015},
#  {'symbol': 'AAPL',
#   'date': '2025-08-18',
#   'open': 231.7,
#   'high': 233.12,
#   'low': 230.11,
#   'close': 230.89,
#   'volume': 37476200,
#   'change': -0.81,
#   'changePercent': -0.34959,
#   'vwap': 231.455},
#  {'symbol': 'AAPL',
#   'date': '2025-08-15',
#   'open': 234,
#   'high': 234.28,
#   'low': 229.34,
#   'close': 231.59,
#   'volume': 56038700,
#   'change': -2.41,
#   'changePercent': -1.03,
#   'vwap': 232.3025},
#  {'symbol': 'AAPL',
#   'date': '2025-08-14',
#   'open': 234.06,
#   'high': 235.12,
#   'low': 230.85,
#   'close': 232.78,
#   'volume': 51916300,
#   'change': -1.28,
#   'changePercent': -0.54687,
#   'vwap': 233.2025},
#  {'symbol': 'AAPL',
#   'date': '2025-08-13',
#   'open': 231.07,
#   'high': 235,
#   'low': 230.43,
#   'close': 233.33,
#   'volume': 69878546,
#   'change': 2.26,
#   'changePercent': 0.97806,
#   'vwap': 232.4575},
#  {'symbol': 'AAPL',
#   'date': '2025-08-12',
#   'open': 228.01,
#   'high': 230.8,
#   'low': 227.07,
#   'close': 229.65,
#   'volume': 55672301,
#   'change': 1.65,
#   'changePercent': 0.71927,
#   'vwap': 228.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-08-11',
#   'open': 227.92,
#   'high': 229.56,
#   'low': 224.76,
#   'close': 227.18,
#   'volume': 61806132,
#   'change': -0.74,
#   'changePercent': -0.32468,
#   'vwap': 227.355},
#  {'symbol': 'AAPL',
#   'date': '2025-08-08',
#   'open': 220.83,
#   'high': 231,
#   'low': 219.25,
#   'close': 229.35,
#   'volume': 113854000,
#   'change': 8.52,
#   'changePercent': 3.86,
#   'vwap': 225.1075},
#  {'symbol': 'AAPL',
#   'date': '2025-08-07',
#   'open': 218.88,
#   'high': 220.85,
#   'low': 216.58,
#   'close': 220.03,
#   'volume': 90224834,
#   'change': 1.16,
#   'changePercent': 0.5254,
#   'vwap': 219.085},
#  {'symbol': 'AAPL',
#   'date': '2025-08-06',
#   'open': 205.63,
#   'high': 215.38,
#   'low': 205.59,
#   'close': 213.25,
#   'volume': 108483103,
#   'change': 7.62,
#   'changePercent': 3.71,
#   'vwap': 209.9625},
#  {'symbol': 'AAPL',
#   'date': '2025-08-05',
#   'open': 203.4,
#   'high': 205.34,
#   'low': 202.16,
#   'close': 202.92,
#   'volume': 44155100,
#   'change': -0.48,
#   'changePercent': -0.23599,
#   'vwap': 203.455},
#  {'symbol': 'AAPL',
#   'date': '2025-08-04',
#   'open': 204.51,
#   'high': 207.88,
#   'low': 201.68,
#   'close': 203.35,
#   'volume': 75109300,
#   'change': -1.16,
#   'changePercent': -0.56721,
#   'vwap': 204.355},
#  {'symbol': 'AAPL',
#   'date': '2025-08-01',
#   'open': 210.87,
#   'high': 213.58,
#   'low': 201.5,
#   'close': 202.38,
#   'volume': 104434500,
#   'change': -8.49,
#   'changePercent': -4.03,
#   'vwap': 207.0825},
#  {'symbol': 'AAPL',
#   'date': '2025-07-31',
#   'open': 208.49,
#   'high': 209.84,
#   'low': 207.16,
#   'close': 207.57,
#   'volume': 80698431,
#   'change': -0.92,
#   'changePercent': -0.44127,
#   'vwap': 208.265},
#  {'symbol': 'AAPL',
#   'date': '2025-07-30',
#   'open': 211.9,
#   'high': 212.39,
#   'low': 207.72,
#   'close': 209.05,
#   'volume': 45512514,
#   'change': -2.84,
#   'changePercent': -1.34,
#   'vwap': 210.265},
#  {'symbol': 'AAPL',
#   'date': '2025-07-29',
#   'open': 214.18,
#   'high': 214.81,
#   'low': 210.82,
#   'close': 211.27,
#   'volume': 51411723,
#   'change': -2.91,
#   'changePercent': -1.36,
#   'vwap': 212.77},
#  {'symbol': 'AAPL',
#   'date': '2025-07-28',
#   'open': 214.03,
#   'high': 214.85,
#   'low': 213.06,
#   'close': 214.05,
#   'volume': 37858017,
#   'change': 0.02,
#   'changePercent': 0.00934448,
#   'vwap': 213.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-25',
#   'open': 214.7,
#   'high': 215.24,
#   'low': 213.4,
#   'close': 213.88,
#   'volume': 40268800,
#   'change': -0.82,
#   'changePercent': -0.38193,
#   'vwap': 214.305},
#  {'symbol': 'AAPL',
#   'date': '2025-07-24',
#   'open': 213.9,
#   'high': 215.69,
#   'low': 213.53,
#   'close': 213.76,
#   'volume': 46022620,
#   'change': -0.14,
#   'changePercent': -0.06545115,
#   'vwap': 214.22},
#  {'symbol': 'AAPL',
#   'date': '2025-07-23',
#   'open': 215,
#   'high': 215.15,
#   'low': 212.41,
#   'close': 214.15,
#   'volume': 46989301,
#   'change': -0.85,
#   'changePercent': -0.39535,
#   'vwap': 214.1775},
#  {'symbol': 'AAPL',
#   'date': '2025-07-22',
#   'open': 213.14,
#   'high': 214.95,
#   'low': 212.23,
#   'close': 214.4,
#   'volume': 46404100,
#   'change': 1.26,
#   'changePercent': 0.59116,
#   'vwap': 213.68},
#  {'symbol': 'AAPL',
#   'date': '2025-07-21',
#   'open': 212.1,
#   'high': 215.78,
#   'low': 211.63,
#   'close': 212.48,
#   'volume': 51377434,
#   'change': 0.38,
#   'changePercent': 0.17916,
#   'vwap': 212.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-18',
#   'open': 210.87,
#   'high': 211.79,
#   'low': 209.7,
#   'close': 211.18,
#   'volume': 48974600,
#   'change': 0.31,
#   'changePercent': 0.14701,
#   'vwap': 210.885},
#  {'symbol': 'AAPL',
#   'date': '2025-07-17',
#   'open': 210.57,
#   'high': 211.8,
#   'low': 209.59,
#   'close': 210.02,
#   'volume': 48068141,
#   'change': -0.55,
#   'changePercent': -0.2612,
#   'vwap': 210.495},
#  {'symbol': 'AAPL',
#   'date': '2025-07-16',
#   'open': 210.3,
#   'high': 212.4,
#   'low': 208.64,
#   'close': 210.16,
#   'volume': 47490532,
#   'change': -0.135,
#   'changePercent': -0.06657156,
#   'vwap': 210.375},
#  {'symbol': 'AAPL',
#   'date': '2025-07-15',
#   'open': 209.22,
#   'high': 211.89,
#   'low': 208.92,
#   'close': 209.11,
#   'volume': 42296339,
#   'change': -0.11,
#   'changePercent': -0.05257624,
#   'vwap': 209.785},
#  {'symbol': 'AAPL',
#   'date': '2025-07-14',
#   'open': 209.93,
#   'high': 210.91,
#   'low': 207.54,
#   'close': 208.62,
#   'volume': 38840111,
#   'change': -1.31,
#   'changePercent': -0.62402,
#   'vwap': 209.25},
#  {'symbol': 'AAPL',
#   'date': '2025-07-11',
#   'open': 210.57,
#   'high': 212.13,
#   'low': 209.86,
#   'close': 211.16,
#   'volume': 39765812,
#   'change': 0.595,
#   'changePercent': 0.28019,
#   'vwap': 210.93},
#  {'symbol': 'AAPL',
#   'date': '2025-07-10',
#   'open': 210.51,
#   'high': 213.48,
#   'low': 210.03,
#   'close': 212.41,
#   'volume': 44443635,
#   'change': 1.91,
#   'changePercent': 0.90257,
#   'vwap': 211.6075},
#  {'symbol': 'AAPL',
#   'date': '2025-07-09',
#   'open': 209.53,
#   'high': 211.33,
#   'low': 207.22,
#   'close': 211.14,
#   'volume': 48749400,
#   'change': 1.61,
#   'changePercent': 0.76839,
#   'vwap': 209.805},
#  {'symbol': 'AAPL',
#   'date': '2025-07-08',
#   'open': 210.1,
#   'high': 211.43,
#   'low': 208.45,
#   'close': 210.01,
#   'volume': 42848928,
#   'change': -0.09,
#   'changePercent': -0.04283674,
#   'vwap': 209.9975},
#  {'symbol': 'AAPL',
#   'date': '2025-07-07',
#   'open': 212.68,
#   'high': 216.23,
#   'low': 208.8,
#   'close': 209.95,
#   'volume': 50229000,
#   'change': -2.73,
#   'changePercent': -1.28,
#   'vwap': 211.915},
#  {'symbol': 'AAPL',
#   'date': '2025-07-03',
#   'open': 212.15,
#   'high': 214.65,
#   'low': 211.81,
#   'close': 213.55,
#   'volume': 34955836,
#   'change': 1.41,
#   'changePercent': 0.65991,
#   'vwap': 213.04},
#  {'symbol': 'AAPL',
#   'date': '2025-07-02',
#   'open': 208.91,
#   'high': 213.34,
#   'low': 208.14,
#   'close': 212.44,
#   'volume': 67941811,
#   'change': 3.53,
#   'changePercent': 1.69,
#   'vwap': 210.7075},
#  {'symbol': 'AAPL',
#   'date': '2025-07-01',
#   'open': 206.67,
#   'high': 210.19,
#   'low': 206.14,
#   'close': 207.82,
#   'volume': 78788900,
#   'change': 1.16,
#   'changePercent': 0.55644,
#   'vwap': 207.705},
#  {'symbol': 'AAPL',
#   'date': '2025-06-30',
#   'open': 202.01,
#   'high': 207.39,
#   'low': 199.26,
#   'close': 205.17,
#   'volume': 91912816,
#   'change': 3.16,
#   'changePercent': 1.56,
#   'vwap': 203.4575},
#  {'symbol': 'AAPL',
#   'date': '2025-06-27',
#   'open': 201.89,
#   'high': 203.22,
#   'low': 200,
#   'close': 201.08,
#   'volume': 73188600,
#   'change': -0.81,
#   'changePercent': -0.40121,
#   'vwap': 201.5475},
#  {'symbol': 'AAPL',
#   'date': '2025-06-26',
#   'open': 201.43,
#   'high': 202.64,
#   'low': 199.46,
#   'close': 201,
#   'volume': 50799121,
#   'change': -0.43,
#   'changePercent': -0.21347,
#   'vwap': 201.1325},
#  {'symbol': 'AAPL',
#   'date': '2025-06-25',
#   'open': 201.45,
#   'high': 203.67,
#   'low': 200.62,
#   'close': 201.56,
#   'volume': 39525730,
#   'change': 0.11,
#   'changePercent': 0.05460412,
#   'vwap': 201.825},
#  {'symbol': 'AAPL',
#   'date': '2025-06-24',
#   'open': 202.59,
#   'high': 203.44,
#   'low': 200.2,
#   'close': 200.3,
#   'volume': 54064033,
#   'change': -2.29,
#   'changePercent': -1.13,
#   'vwap': 201.6325},
#  {'symbol': 'AAPL',
#   'date': '2025-06-23',
#   'open': 201.63,
#   'high': 202.3,
#   'low': 198.96,
#   'close': 201.5,
#   'volume': 55814300,
#   'change': -0.125,
#   'changePercent': -0.06447453,
#   'vwap': 201.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-06-20',
#   'open': 198.24,
#   'high': 201.7,
#   'low': 196.86,
#   'close': 201,
#   'volume': 96813542,
#   'change': 2.76,
#   'changePercent': 1.39,
#   'vwap': 199.45},
#  {'symbol': 'AAPL',
#   'date': '2025-06-18',
#   'open': 195.94,
#   'high': 197.57,
#   'low': 195.07,
#   'close': 196.58,
#   'volume': 45394700,
#   'change': 0.64,
#   'changePercent': 0.32663,
#   'vwap': 196.29},
#  {'symbol': 'AAPL',
#   'date': '2025-06-17',
#   'open': 197.2,
#   'high': 198.39,
#   'low': 195.21,
#   'close': 195.64,
#   'volume': 38856200,
#   'change': -1.56,
#   'changePercent': -0.79108,
#   'vwap': 196.61},
#  {'symbol': 'AAPL',
#   'date': '2025-06-16',
#   'open': 197.3,
#   'high': 198.69,
#   'low': 196.56,
#   'close': 198.42,
#   'volume': 43020700,
#   'change': 1.12,
#   'changePercent': 0.56766,
#   'vwap': 197.7425},
#  {'symbol': 'AAPL',
#   'date': '2025-06-13',
#   'open': 199.73,
#   'high': 200.37,
#   'low': 195.7,
#   'close': 196.45,
#   'volume': 51447349,
#   'change': -3.28,
#   'changePercent': -1.64,
#   'vwap': 198.0625},
#  {'symbol': 'AAPL',
#   'date': '2025-06-12',
#   'open': 199.08,
#   'high': 199.68,
#   'low': 197.36,
#   'close': 199.2,
#   'volume': 43904635,
#   'change': 0.12,
#   'changePercent': 0.06027728,
#   'vwap': 198.83},
#  {'symbol': 'AAPL',
#   'date': '2025-06-11',
#   'open': 203.5,
#   'high': 204.5,
#   'low': 198.41,
#   'close': 198.78,
#   'volume': 60989900,
#   'change': -4.72,
#   'changePercent': -2.32,
#   'vwap': 201.2975},
#  {'symbol': 'AAPL',
#   'date': '2025-06-10',
#   'open': 200.6,
#   'high': 204.35,
#   'low': 200.57,
#   'close': 202.67,
#   'volume': 54672608,
#   'change': 2.07,
#   'changePercent': 1.03,
#   'vwap': 202.0475},
#  {'symbol': 'AAPL',
#   'date': '2025-06-09',
#   'open': 204.39,
#   'high': 206,
#   'low': 200.02,
#   'close': 201.45,
#   'volume': 72862600,
#   'change': -2.94,
#   'changePercent': -1.44,
#   'vwap': 202.965},
#  {'symbol': 'AAPL',
#   'date': '2025-06-06',
#   'open': 203,
#   'high': 205.7,
#   'low': 202.05,
#   'close': 203.92,
#   'volume': 46607700,
#   'change': 0.92,
#   'changePercent': 0.4532,
#   'vwap': 203.6675},
#  {'symbol': 'AAPL',
#   'date': '2025-06-05',
#   'open': 203.5,
#   'high': 204.75,
#   'low': 200.15,
#   'close': 200.63,
#   'volume': 55221235,
#   'change': -2.87,
#   'changePercent': -1.41,
#   'vwap': 202.2575},
#  {'symbol': 'AAPL',
#   'date': '2025-06-04',
#   'open': 202.91,
#   'high': 206.24,
#   'low': 202.1,
#   'close': 202.82,
#   'volume': 43604000,
#   'change': -0.09,
#   'changePercent': -0.04435464,
#   'vwap': 203.5175},
#  {'symbol': 'AAPL',
#   'date': '2025-06-03',
#   'open': 201.35,
#   'high': 203.77,
#   'low': 200.96,
#   'close': 203.27,
#   'volume': 46381600,
#   'change': 1.92,
#   'changePercent': 0.95356,
#   'vwap': 202.3375},
#  {'symbol': 'AAPL',
#   'date': '2025-06-02',
#   'open': 200.28,
#   'high': 202.13,
#   'low': 200.12,
#   'close': 201.7,
#   'volume': 35423300,
#   'change': 1.42,
#   'changePercent': 0.70901,
#   'vwap': 201.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-05-30',
#   'open': 199.37,
#   'high': 201.96,
#   'low': 196.78,
#   'close': 200.85,
#   'volume': 70819942,
#   'change': 1.48,
#   'changePercent': 0.74234,
#   'vwap': 199.74},
#  {'symbol': 'AAPL',
#   'date': '2025-05-29',
#   'open': 203.58,
#   'high': 203.81,
#   'low': 198.51,
#   'close': 199.95,
#   'volume': 51477938,
#   'change': -3.62,
#   'changePercent': -1.78,
#   'vwap': 201.4625},
#  {'symbol': 'AAPL',
#   'date': '2025-05-28',
#   'open': 200.59,
#   'high': 202.73,
#   'low': 199.9,
#   'close': 200.42,
#   'volume': 45339700,
#   'change': -0.17,
#   'changePercent': -0.08474999,
#   'vwap': 200.91},
#  {'symbol': 'AAPL',
#   'date': '2025-05-27',
#   'open': 198.3,
#   'high': 200.74,
#   'low': 197.43,
#   'close': 200.21,
#   'volume': 56288500,
#   'change': 1.91,
#   'changePercent': 0.96319,
#   'vwap': 199.17},
#  {'symbol': 'AAPL',
#   'date': '2025-05-23',
#   'open': 193.67,
#   'high': 197.7,
#   'low': 193.46,
#   'close': 195.27,
#   'volume': 78432918,
#   'change': 1.61,
#   'changePercent': 0.82615,
#   'vwap': 195.025},
#  {'symbol': 'AAPL',
#   'date': '2025-05-22',
#   'open': 200.71,
#   'high': 202.75,
#   'low': 199.7,
#   'close': 201.36,
#   'volume': 46742407,
#   'change': 0.65,
#   'changePercent': 0.32385,
#   'vwap': 201.13},
#  {'symbol': 'AAPL',
#   'date': '2025-05-21',
#   'open': 205.17,
#   'high': 207.04,
#   'low': 200.71,
#   'close': 202.09,
#   'volume': 59211800,
#   'change': -3.08,
#   'changePercent': -1.5,
#   'vwap': 203.7525},
#  {'symbol': 'AAPL',
#   'date': '2025-05-20',
#   'open': 207.67,
#   'high': 208.47,
#   'low': 205.03,
#   'close': 206.86,
#   'volume': 42496635,
#   'change': -0.81,
#   'changePercent': -0.39004,
#   'vwap': 207.0075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-19',
#   'open': 207.91,
#   'high': 209.48,
#   'low': 204.26,
#   'close': 208.78,
#   'volume': 46140527,
#   'change': 0.87,
#   'changePercent': 0.41845,
#   'vwap': 207.6075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-16',
#   'open': 212.36,
#   'high': 212.57,
#   'low': 209.77,
#   'close': 211.26,
#   'volume': 54737900,
#   'change': -1.1,
#   'changePercent': -0.51799,
#   'vwap': 211.49},
#  {'symbol': 'AAPL',
#   'date': '2025-05-15',
#   'open': 210.95,
#   'high': 212.96,
#   'low': 209.54,
#   'close': 211.45,
#   'volume': 45029500,
#   'change': 0.5,
#   'changePercent': 0.23702,
#   'vwap': 211.225},
#  {'symbol': 'AAPL',
#   'date': '2025-05-14',
#   'open': 212.43,
#   'high': 213.94,
#   'low': 210.58,
#   'close': 212.33,
#   'volume': 49325825,
#   'change': -0.1,
#   'changePercent': -0.04707433,
#   'vwap': 212.32},
#  {'symbol': 'AAPL',
#   'date': '2025-05-13',
#   'open': 210.43,
#   'high': 213.4,
#   'low': 209,
#   'close': 212.93,
#   'volume': 51909332,
#   'change': 2.5,
#   'changePercent': 1.19,
#   'vwap': 211.44},
#  {'symbol': 'AAPL',
#   'date': '2025-05-12',
#   'open': 210.97,
#   'high': 211.27,
#   'low': 206.75,
#   'close': 210.79,
#   'volume': 63775814,
#   'change': -0.18,
#   'changePercent': -0.08532019,
#   'vwap': 209.945},
#  {'symbol': 'AAPL',
#   'date': '2025-05-09',
#   'open': 199,
#   'high': 200.54,
#   'low': 197.54,
#   'close': 198.53,
#   'volume': 36453923,
#   'change': -0.47,
#   'changePercent': -0.23618,
#   'vwap': 198.9025},
#  {'symbol': 'AAPL',
#   'date': '2025-05-08',
#   'open': 197.72,
#   'high': 200.05,
#   'low': 194.68,
#   'close': 197.49,
#   'volume': 50478900,
#   'change': -0.23,
#   'changePercent': -0.11633,
#   'vwap': 197.485},
#  {'symbol': 'AAPL',
#   'date': '2025-05-07',
#   'open': 199.17,
#   'high': 199.44,
#   'low': 193.25,
#   'close': 196.25,
#   'volume': 68616943,
#   'change': -2.92,
#   'changePercent': -1.47,
#   'vwap': 197.0275},
#  {'symbol': 'AAPL',
#   'date': '2025-05-06',
#   'open': 198.21,
#   'high': 200.65,
#   'low': 197.02,
#   'close': 198.51,
#   'volume': 51216500,
#   'change': 0.3,
#   'changePercent': 0.15135,
#   'vwap': 198.5975},
#  {'symbol': 'AAPL',
#   'date': '2025-05-05',
#   'open': 203.1,
#   'high': 204.1,
#   'low': 198.21,
#   'close': 198.89,
#   'volume': 69018500,
#   'change': -4.21,
#   'changePercent': -2.07,
#   'vwap': 201.075},
#  {'symbol': 'AAPL',
#   'date': '2025-05-02',
#   'open': 206.09,
#   'high': 206.99,
#   'low': 202.16,
#   'close': 205.35,
#   'volume': 101010621,
#   'change': -0.74,
#   'changePercent': -0.35907,
#   'vwap': 205.1475},
#  {'symbol': 'AAPL',
#   'date': '2025-05-01',
#   'open': 209.08,
#   'high': 214.56,
#   'low': 208.9,
#   'close': 213.32,
#   'volume': 57365700,
#   'change': 4.24,
#   'changePercent': 2.03,
#   'vwap': 211.465},
#  {'symbol': 'AAPL',
#   'date': '2025-04-30',
#   'open': 209.3,
#   'high': 213.58,
#   'low': 206.67,
#   'close': 212.5,
#   'volume': 52286500,
#   'change': 3.2,
#   'changePercent': 1.53,
#   'vwap': 210.5125},
#  {'symbol': 'AAPL',
#   'date': '2025-04-29',
#   'open': 208.69,
#   'high': 212.24,
#   'low': 208.37,
#   'close': 211.21,
#   'volume': 36827633,
#   'change': 2.52,
#   'changePercent': 1.21,
#   'vwap': 210.1275},
#  {'symbol': 'AAPL',
#   'date': '2025-04-28',
#   'open': 210,
#   'high': 211.5,
#   'low': 207.46,
#   'close': 210.14,
#   'volume': 38743100,
#   'change': 0.14,
#   'changePercent': 0.06666667,
#   'vwap': 209.775},
#  {'symbol': 'AAPL',
#   'date': '2025-04-25',
#   'open': 206.37,
#   'high': 209.75,
#   'low': 206.2,
#   'close': 209.28,
#   'volume': 38222300,
#   'change': 2.91,
#   'changePercent': 1.41,
#   'vwap': 207.9},
#  {'symbol': 'AAPL',
#   'date': '2025-04-24',
#   'open': 204.89,
#   'high': 208.83,
#   'low': 202.94,
#   'close': 208.37,
#   'volume': 47311000,
#   'change': 3.48,
#   'changePercent': 1.7,
#   'vwap': 206.2575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-23',
#   'open': 206,
#   'high': 208,
#   'low': 202.8,
#   'close': 204.6,
#   'volume': 52929200,
#   'change': -1.4,
#   'changePercent': -0.67961,
#   'vwap': 205.35},
#  {'symbol': 'AAPL',
#   'date': '2025-04-22',
#   'open': 196.12,
#   'high': 201.59,
#   'low': 195.97,
#   'close': 199.74,
#   'volume': 52976400,
#   'change': 3.62,
#   'changePercent': 1.85,
#   'vwap': 198.355},
#  {'symbol': 'AAPL',
#   'date': '2025-04-21',
#   'open': 193.27,
#   'high': 193.8,
#   'low': 189.81,
#   'close': 193.16,
#   'volume': 46742537,
#   'change': -0.105,
#   'changePercent': -0.0569152,
#   'vwap': 192.51},
#  {'symbol': 'AAPL',
#   'date': '2025-04-17',
#   'open': 197.2,
#   'high': 198.83,
#   'low': 194.42,
#   'close': 196.98,
#   'volume': 52164700,
#   'change': -0.22,
#   'changePercent': -0.11156,
#   'vwap': 196.8575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-16',
#   'open': 198.36,
#   'high': 200.7,
#   'low': 192.37,
#   'close': 194.27,
#   'volume': 59732423,
#   'change': -4.09,
#   'changePercent': -2.06,
#   'vwap': 196.425},
#  {'symbol': 'AAPL',
#   'date': '2025-04-15',
#   'open': 201.86,
#   'high': 203.51,
#   'low': 199.8,
#   'close': 202.14,
#   'volume': 51343900,
#   'change': 0.285,
#   'changePercent': 0.13871,
#   'vwap': 201.8275},
#  {'symbol': 'AAPL',
#   'date': '2025-04-14',
#   'open': 211.44,
#   'high': 212.94,
#   'low': 201.16,
#   'close': 202.52,
#   'volume': 101352911,
#   'change': -8.92,
#   'changePercent': -4.22,
#   'vwap': 207.015},
#  {'symbol': 'AAPL',
#   'date': '2025-04-11',
#   'open': 186.1,
#   'high': 199.54,
#   'low': 186.06,
#   'close': 198.15,
#   'volume': 87435915,
#   'change': 12.05,
#   'changePercent': 6.48,
#   'vwap': 192.4625},
#  {'symbol': 'AAPL',
#   'date': '2025-04-10',
#   'open': 189.07,
#   'high': 194.78,
#   'low': 183,
#   'close': 190.42,
#   'volume': 121880000,
#   'change': 1.35,
#   'changePercent': 0.71402,
#   'vwap': 189.3175},
#  {'symbol': 'AAPL',
#   'date': '2025-04-09',
#   'open': 171.95,
#   'high': 200.61,
#   'low': 171.89,
#   'close': 198.85,
#   'volume': 184395900,
#   'change': 26.9,
#   'changePercent': 15.64,
#   'vwap': 185.825},
#  {'symbol': 'AAPL',
#   'date': '2025-04-08',
#   'open': 186.7,
#   'high': 190.34,
#   'low': 169.21,
#   'close': 172.42,
#   'volume': 120859500,
#   'change': -14.28,
#   'changePercent': -7.65,
#   'vwap': 179.6675},
#  {'symbol': 'AAPL',
#   'date': '2025-04-07',
#   'open': 177.2,
#   'high': 194.15,
#   'low': 174.62,
#   'close': 181.46,
#   'volume': 160466300,
#   'change': 4.26,
#   'changePercent': 2.4,
#   'vwap': 181.8575},
#  {'symbol': 'AAPL',
#   'date': '2025-04-04',
#   'open': 193.89,
#   'high': 199.88,
#   'low': 187.34,
#   'close': 188.38,
#   'volume': 125910913,
#   'change': -5.51,
#   'changePercent': -2.84,
#   'vwap': 192.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-04-03',
#   'open': 205.54,
#   'high': 207.49,
#   'low': 201.25,
#   'close': 203.19,
#   'volume': 103419006,
#   'change': -2.35,
#   'changePercent': -1.14,
#   'vwap': 204.3675},
#  {'symbol': 'AAPL',
#   'date': '2025-04-02',
#   'open': 221.32,
#   'high': 225.19,
#   'low': 221.02,
#   'close': 223.89,
#   'volume': 35905904,
#   'change': 2.57,
#   'changePercent': 1.16,
#   'vwap': 222.855},
#  {'symbol': 'AAPL',
#   'date': '2025-04-01',
#   'open': 219.81,
#   'high': 223.68,
#   'low': 218.9,
#   'close': 223.19,
#   'volume': 36412740,
#   'change': 3.38,
#   'changePercent': 1.54,
#   'vwap': 221.395},
#  {'symbol': 'AAPL',
#   'date': '2025-03-31',
#   'open': 217.01,
#   'high': 225.62,
#   'low': 216.23,
#   'close': 222.13,
#   'volume': 65299321,
#   'change': 5.13,
#   'changePercent': 2.36,
#   'vwap': 220.2475},
#  {'symbol': 'AAPL',
#   'date': '2025-03-28',
#   'open': 221.67,
#   'high': 223.81,
#   'low': 217.68,
#   'close': 217.9,
#   'volume': 39818617,
#   'change': -3.77,
#   'changePercent': -1.7,
#   'vwap': 220.265},
#  {'symbol': 'AAPL',
#   'date': '2025-03-27',
#   'open': 221.39,
#   'high': 224.99,
#   'low': 220.56,
#   'close': 223.85,
#   'volume': 37094800,
#   'change': 2.46,
#   'changePercent': 1.11,
#   'vwap': 222.6975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-26',
#   'open': 223.51,
#   'high': 225.02,
#   'low': 220.47,
#   'close': 221.53,
#   'volume': 34532656,
#   'change': -1.98,
#   'changePercent': -0.88587,
#   'vwap': 222.6325},
#  {'symbol': 'AAPL',
#   'date': '2025-03-25',
#   'open': 220.77,
#   'high': 224.1,
#   'low': 220.08,
#   'close': 223.75,
#   'volume': 34493600,
#   'change': 2.98,
#   'changePercent': 1.35,
#   'vwap': 222.175},
#  {'symbol': 'AAPL',
#   'date': '2025-03-24',
#   'open': 221,
#   'high': 221.48,
#   'low': 218.58,
#   'close': 220.73,
#   'volume': 44299500,
#   'change': -0.27,
#   'changePercent': -0.12217,
#   'vwap': 220.4475},
#  {'symbol': 'AAPL',
#   'date': '2025-03-21',
#   'open': 211.56,
#   'high': 218.84,
#   'low': 211.28,
#   'close': 218.27,
#   'volume': 94127800,
#   'change': 6.71,
#   'changePercent': 3.17,
#   'vwap': 214.9875},
#  {'symbol': 'AAPL',
#   'date': '2025-03-20',
#   'open': 213.99,
#   'high': 217.49,
#   'low': 212.22,
#   'close': 214.1,
#   'volume': 48862947,
#   'change': 0.11,
#   'changePercent': 0.05140427,
#   'vwap': 214.45},
#  {'symbol': 'AAPL',
#   'date': '2025-03-19',
#   'open': 214.22,
#   'high': 218.76,
#   'low': 213.75,
#   'close': 215.24,
#   'volume': 54385400,
#   'change': 1.02,
#   'changePercent': 0.47615,
#   'vwap': 215.4925},
#  {'symbol': 'AAPL',
#   'date': '2025-03-18',
#   'open': 214.16,
#   'high': 215.15,
#   'low': 211.49,
#   'close': 212.69,
#   'volume': 42432426,
#   'change': -1.47,
#   'changePercent': -0.6864,
#   'vwap': 213.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-03-17',
#   'open': 213.31,
#   'high': 215.22,
#   'low': 209.97,
#   'close': 214,
#   'volume': 48073426,
#   'change': 0.69,
#   'changePercent': 0.32347,
#   'vwap': 213.125},
#  {'symbol': 'AAPL',
#   'date': '2025-03-14',
#   'open': 211.25,
#   'high': 213.95,
#   'low': 209.58,
#   'close': 213.49,
#   'volume': 60107600,
#   'change': 2.24,
#   'changePercent': 1.06,
#   'vwap': 212.0675},
#  {'symbol': 'AAPL',
#   'date': '2025-03-13',
#   'open': 215.95,
#   'high': 216.84,
#   'low': 208.42,
#   'close': 209.68,
#   'volume': 61368330,
#   'change': -6.27,
#   'changePercent': -2.9,
#   'vwap': 212.7225},
#  {'symbol': 'AAPL',
#   'date': '2025-03-12',
#   'open': 220.14,
#   'high': 221.75,
#   'low': 214.91,
#   'close': 216.98,
#   'volume': 62547500,
#   'change': -3.16,
#   'changePercent': -1.44,
#   'vwap': 218.445},
#  {'symbol': 'AAPL',
#   'date': '2025-03-11',
#   'open': 223.81,
#   'high': 225.84,
#   'low': 217.45,
#   'close': 220.84,
#   'volume': 76137410,
#   'change': -2.97,
#   'changePercent': -1.33,
#   'vwap': 221.985},
#  {'symbol': 'AAPL',
#   'date': '2025-03-10',
#   'open': 235.54,
#   'high': 236.16,
#   'low': 224.22,
#   'close': 227.48,
#   'volume': 72071200,
#   'change': -8.06,
#   'changePercent': -3.42,
#   'vwap': 230.85},
#  {'symbol': 'AAPL',
#   'date': '2025-03-07',
#   'open': 235.11,
#   'high': 241.37,
#   'low': 234.76,
#   'close': 239.07,
#   'volume': 46273600,
#   'change': 3.97,
#   'changePercent': 1.68,
#   'vwap': 237.5775},
#  {'symbol': 'AAPL',
#   'date': '2025-03-06',
#   'open': 234.44,
#   'high': 237.86,
#   'low': 233.16,
#   'close': 235.33,
#   'volume': 45170419,
#   'change': 0.895,
#   'changePercent': 0.37963,
#   'vwap': 235.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-05',
#   'open': 235.42,
#   'high': 236.55,
#   'low': 229.23,
#   'close': 235.74,
#   'volume': 47227643,
#   'change': 0.32,
#   'changePercent': 0.13593,
#   'vwap': 234.235},
#  {'symbol': 'AAPL',
#   'date': '2025-03-04',
#   'open': 237.71,
#   'high': 240.07,
#   'low': 234.68,
#   'close': 235.93,
#   'volume': 53798100,
#   'change': -1.78,
#   'changePercent': -0.74881,
#   'vwap': 237.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-03-03',
#   'open': 241.79,
#   'high': 244.03,
#   'low': 236.11,
#   'close': 238.03,
#   'volume': 47184000,
#   'change': -3.76,
#   'changePercent': -1.56,
#   'vwap': 239.99},
#  {'symbol': 'AAPL',
#   'date': '2025-02-28',
#   'open': 236.95,
#   'high': 242.09,
#   'low': 230.2,
#   'close': 241.84,
#   'volume': 56833400,
#   'change': 4.89,
#   'changePercent': 2.06,
#   'vwap': 237.77},
#  {'symbol': 'AAPL',
#   'date': '2025-02-27',
#   'open': 239.41,
#   'high': 242.46,
#   'low': 237.06,
#   'close': 237.3,
#   'volume': 41153639,
#   'change': -2.11,
#   'changePercent': -0.88133,
#   'vwap': 239.0575},
#  {'symbol': 'AAPL',
#   'date': '2025-02-26',
#   'open': 244.33,
#   'high': 244.98,
#   'low': 239.13,
#   'close': 240.36,
#   'volume': 44433600,
#   'change': -3.97,
#   'changePercent': -1.62,
#   'vwap': 242.2},
#  {'symbol': 'AAPL',
#   'date': '2025-02-25',
#   'open': 248,
#   'high': 250,
#   'low': 244.91,
#   'close': 247.04,
#   'volume': 48013300,
#   'change': -0.96,
#   'changePercent': -0.3871,
#   'vwap': 247.4875},
#  {'symbol': 'AAPL',
#   'date': '2025-02-24',
#   'open': 244.93,
#   'high': 248.86,
#   'low': 244.42,
#   'close': 247.1,
#   'volume': 51326400,
#   'change': 2.17,
#   'changePercent': 0.88597,
#   'vwap': 246.3275},
#  {'symbol': 'AAPL',
#   'date': '2025-02-21',
#   'open': 245.95,
#   'high': 248.69,
#   'low': 245.22,
#   'close': 245.55,
#   'volume': 53197431,
#   'change': -0.4,
#   'changePercent': -0.16263,
#   'vwap': 246.3525},
#  {'symbol': 'AAPL',
#   'date': '2025-02-20',
#   'open': 244.94,
#   'high': 246.78,
#   'low': 244.29,
#   'close': 245.83,
#   'volume': 32316907,
#   'change': 0.89,
#   'changePercent': 0.36335,
#   'vwap': 245.46},
#  {'symbol': 'AAPL',
#   'date': '2025-02-19',
#   'open': 244.66,
#   'high': 246.01,
#   'low': 243.16,
#   'close': 244.87,
#   'volume': 32204215,
#   'change': 0.21,
#   'changePercent': 0.0858334,
#   'vwap': 244.675},
#  {'symbol': 'AAPL',
#   'date': '2025-02-18',
#   'open': 244.15,
#   'high': 245.18,
#   'low': 241.84,
#   'close': 244.47,
#   'volume': 48822500,
#   'change': 0.32,
#   'changePercent': 0.13107,
#   'vwap': 243.91},
#  {'symbol': 'AAPL',
#   'date': '2025-02-14',
#   'open': 241.25,
#   'high': 245.55,
#   'low': 240.99,
#   'close': 244.6,
#   'volume': 40896227,
#   'change': 3.35,
#   'changePercent': 1.39,
#   'vwap': 243.0975},
#  {'symbol': 'AAPL',
#   'date': '2025-02-13',
#   'open': 236.91,
#   'high': 242.34,
#   'low': 235.57,
#   'close': 241.53,
#   'volume': 53614100,
#   'change': 4.62,
#   'changePercent': 1.95,
#   'vwap': 239.0875},
#  {'symbol': 'AAPL',
#   'date': '2025-02-12',
#   'open': 231.2,
#   'high': 236.96,
#   'low': 230.68,
#   'close': 236.87,
#   'volume': 45243300,
#   'change': 5.67,
#   'changePercent': 2.45,
#   'vwap': 233.9275},
#  {'symbol': 'AAPL',
#   'date': '2025-02-11',
#   'open': 228.2,
#   'high': 235.23,
#   'low': 228.13,
#   'close': 232.62,
#   'volume': 53718400,
#   'change': 4.42,
#   'changePercent': 1.94,
#   'vwap': 231.045},
#  {'symbol': 'AAPL',
#   'date': '2025-02-10',
#   'open': 229.57,
#   'high': 230.59,
#   'low': 227.2,
#   'close': 227.65,
#   'volume': 33115645,
#   'change': -1.92,
#   'changePercent': -0.83635,
#   'vwap': 228.7525},
#  {'symbol': 'AAPL',
#   'date': '2025-02-07',
#   'open': 232.6,
#   'high': 234,
#   'low': 227.26,
#   'close': 227.63,
#   'volume': 39707224,
#   'change': -4.97,
#   'changePercent': -2.14,
#   'vwap': 230.3725},
#  {'symbol': 'AAPL',
#   'date': '2025-02-06',
#   'open': 231.29,
#   'high': 233.8,
#   'low': 230.43,
#   'close': 233.22,
#   'volume': 29925349,
#   'change': 1.94,
#   'changePercent': 0.83445,
#   'vwap': 232.185},
#  {'symbol': 'AAPL',
#   'date': '2025-02-05',
#   'open': 228.53,
#   'high': 232.67,
#   'low': 228.27,
#   'close': 232.47,
#   'volume': 39664989,
#   'change': 3.94,
#   'changePercent': 1.72,
#   'vwap': 230.485},
#  {'symbol': 'AAPL',
#   'date': '2025-02-04',
#   'open': 227.25,
#   'high': 233.13,
#   'low': 226.65,
#   'close': 232.8,
#   'volume': 45067301,
#   'change': 5.55,
#   'changePercent': 2.44,
#   'vwap': 229.9575},
#  {'symbol': 'AAPL',
#   'date': '2025-02-03',
#   'open': 229.99,
#   'high': 231.83,
#   'low': 225.7,
#   'close': 228.01,
#   'volume': 73063301,
#   'change': -1.98,
#   'changePercent': -0.86091,
#   'vwap': 228.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-01-31',
#   'open': 247.19,
#   'high': 247.19,
#   'low': 233.44,
#   'close': 236,
#   'volume': 101075128,
#   'change': -11.19,
#   'changePercent': -4.53,
#   'vwap': 240.955},
#  {'symbol': 'AAPL',
#   'date': '2025-01-30',
#   'open': 238.67,
#   'high': 240.79,
#   'low': 237.21,
#   'close': 237.59,
#   'volume': 55658300,
#   'change': -1.07,
#   'changePercent': -0.45251,
#   'vwap': 238.565},
#  {'symbol': 'AAPL',
#   'date': '2025-01-29',
#   'open': 234.12,
#   'high': 239.86,
#   'low': 234.01,
#   'close': 239.36,
#   'volume': 45486100,
#   'change': 5.24,
#   'changePercent': 2.24,
#   'vwap': 236.8375},
#  {'symbol': 'AAPL',
#   'date': '2025-01-28',
#   'open': 230.85,
#   'high': 240.19,
#   'low': 230.81,
#   'close': 238.26,
#   'volume': 75707600,
#   'change': 7.41,
#   'changePercent': 3.21,
#   'vwap': 235.0275},
#  {'symbol': 'AAPL',
#   'date': '2025-01-27',
#   'open': 224.02,
#   'high': 232.15,
#   'low': 223.98,
#   'close': 229.86,
#   'volume': 94863418,
#   'change': 5.84,
#   'changePercent': 2.61,
#   'vwap': 227.5025},
#  {'symbol': 'AAPL',
#   'date': '2025-01-24',
#   'open': 224.78,
#   'high': 225.63,
#   'low': 221.41,
#   'close': 222.78,
#   'volume': 54697907,
#   'change': -2,
#   'changePercent': -0.88976,
#   'vwap': 223.65},
#  {'symbol': 'AAPL',
#   'date': '2025-01-23',
#   'open': 224.74,
#   'high': 227.03,
#   'low': 222.3,
#   'close': 223.66,
#   'volume': 60234800,
#   'change': -1.08,
#   'changePercent': -0.48056,
#   'vwap': 224.4325},
#  {'symbol': 'AAPL',
#   'date': '2025-01-22',
#   'open': 219.79,
#   'high': 224.12,
#   'low': 219.79,
#   'close': 223.83,
#   'volume': 64126500,
#   'change': 4.04,
#   'changePercent': 1.84,
#   'vwap': 221.8825},
#  {'symbol': 'AAPL',
#   'date': '2025-01-21',
#   'open': 224,
#   'high': 224.42,
#   'low': 219.38,
#   'close': 222.64,
#   'volume': 98070429,
#   'change': -1.36,
#   'changePercent': -0.60714,
#   'vwap': 222.61},
#  {'symbol': 'AAPL',
#   'date': '2025-01-17',
#   'open': 232.12,
#   'high': 232.29,
#   'low': 228.48,
#   'close': 229.98,
#   'volume': 68488301,
#   'change': -2.14,
#   'changePercent': -0.92194,
#   'vwap': 230.7175},
#  {'symbol': 'AAPL',
#   'date': '2025-01-16',
#   'open': 237.35,
#   'high': 238.01,
#   'low': 228.03,
#   'close': 228.26,
#   'volume': 71759100,
#   'change': -9.09,
#   'changePercent': -3.83,
#   'vwap': 232.9125},
#  {'symbol': 'AAPL',
#   'date': '2025-01-15',
#   'open': 234.64,
#   'high': 238.96,
#   'low': 234.43,
#   'close': 237.87,
#   'volume': 39832000,
#   'change': 3.24,
#   'changePercent': 1.38,
#   'vwap': 236.475},
#  {'symbol': 'AAPL',
#   'date': '2025-01-14',
#   'open': 234.75,
#   'high': 236.12,
#   'low': 232.47,
#   'close': 233.28,
#   'volume': 39435300,
#   'change': -1.47,
#   'changePercent': -0.6262,
#   'vwap': 234.155},
#  {'symbol': 'AAPL',
#   'date': '2025-01-13',
#   'open': 233.53,
#   'high': 234.67,
#   'low': 229.72,
#   'close': 234.4,
#   'volume': 49630725,
#   'change': 0.87,
#   'changePercent': 0.37254,
#   'vwap': 233.08},
#  {'symbol': 'AAPL',
#   'date': '2025-01-10',
#   'open': 240.01,
#   'high': 240.16,
#   'low': 233,
#   'close': 236.85,
#   'volume': 61710900,
#   'change': -3.16,
#   'changePercent': -1.32,
#   'vwap': 237.505},
#  {'symbol': 'AAPL',
#   'date': '2025-01-08',
#   'open': 241.92,
#   'high': 243.71,
#   'low': 240.05,
#   'close': 242.7,
#   'volume': 37628940,
#   'change': 0.78,
#   'changePercent': 0.32242,
#   'vwap': 242.095},
#  {'symbol': 'AAPL',
#   'date': '2025-01-07',
#   'open': 242.98,
#   'high': 245.55,
#   'low': 241.35,
#   'close': 242.21,
#   'volume': 40856000,
#   'change': -0.77,
#   'changePercent': -0.3169,
#   'vwap': 243.0225},
#  {'symbol': 'AAPL',
#   'date': '2025-01-06',
#   'open': 244.31,
#   'high': 247.33,
#   'low': 243.2,
#   'close': 245,
#   'volume': 45045600,
#   'change': 0.69,
#   'changePercent': 0.28243,
#   'vwap': 244.96},
#  {'symbol': 'AAPL',
#   'date': '2025-01-03',
#   'open': 243.36,
#   'high': 244.18,
#   'low': 241.89,
#   'close': 243.36,
#   'volume': 40244114,
#   'change': 0,
#   'changePercent': 0,
#   'vwap': 243.1975},
#  {'symbol': 'AAPL',
#   'date': '2025-01-02',
#   'open': 248.93,
#   'high': 249.1,
#   'low': 241.82,
#   'close': 243.85,
#   'volume': 55740731,
#   'change': -5.08,
#   'changePercent': -2.04,
#   'vwap': 245.925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-31',
#   'open': 252.44,
#   'high': 253.28,
#   'low': 249.43,
#   'close': 250.42,
#   'volume': 39480718,
#   'change': -2.02,
#   'changePercent': -0.80019,
#   'vwap': 251.3925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-30',
#   'open': 252.23,
#   'high': 253.5,
#   'low': 250.75,
#   'close': 252.2,
#   'volume': 35557542,
#   'change': -0.03,
#   'changePercent': -0.01189391,
#   'vwap': 252.17},
#  {'symbol': 'AAPL',
#   'date': '2024-12-27',
#   'open': 257.83,
#   'high': 258.7,
#   'low': 253.06,
#   'close': 255.59,
#   'volume': 42355321,
#   'change': -2.24,
#   'changePercent': -0.86879,
#   'vwap': 256.295},
#  {'symbol': 'AAPL',
#   'date': '2024-12-26',
#   'open': 258.19,
#   'high': 260.1,
#   'low': 257.63,
#   'close': 259.02,
#   'volume': 27262983,
#   'change': 0.83,
#   'changePercent': 0.32147,
#   'vwap': 258.735},
#  {'symbol': 'AAPL',
#   'date': '2024-12-24',
#   'open': 255.49,
#   'high': 258.21,
#   'low': 255.29,
#   'close': 258.2,
#   'volume': 23234705,
#   'change': 2.71,
#   'changePercent': 1.06,
#   'vwap': 256.7975},
#  {'symbol': 'AAPL',
#   'date': '2024-12-23',
#   'open': 254.77,
#   'high': 255.65,
#   'low': 253.45,
#   'close': 255.27,
#   'volume': 40858800,
#   'change': 0.5,
#   'changePercent': 0.19626,
#   'vwap': 254.785},
#  {'symbol': 'AAPL',
#   'date': '2024-12-20',
#   'open': 248.04,
#   'high': 255,
#   'low': 245.69,
#   'close': 254.49,
#   'volume': 147495300,
#   'change': 6.45,
#   'changePercent': 2.6,
#   'vwap': 250.805},
#  {'symbol': 'AAPL',
#   'date': '2024-12-19',
#   'open': 247.5,
#   'high': 252,
#   'low': 247.09,
#   'close': 249.79,
#   'volume': 60882300,
#   'change': 2.29,
#   'changePercent': 0.92525,
#   'vwap': 249.095},
#  {'symbol': 'AAPL',
#   'date': '2024-12-18',
#   'open': 252.16,
#   'high': 254.28,
#   'low': 247.74,
#   'close': 248.05,
#   'volume': 56774101,
#   'change': -4.11,
#   'changePercent': -1.63,
#   'vwap': 250.5575},
#  {'symbol': 'AAPL',
#   'date': '2024-12-17',
#   'open': 250.08,
#   'high': 253.83,
#   'low': 249.78,
#   'close': 253.48,
#   'volume': 51356400,
#   'change': 3.4,
#   'changePercent': 1.36,
#   'vwap': 251.7925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-16',
#   'open': 247.99,
#   'high': 251.38,
#   'low': 247.65,
#   'close': 251.04,
#   'volume': 51694800,
#   'change': 3.05,
#   'changePercent': 1.23,
#   'vwap': 249.515},
#  {'symbol': 'AAPL',
#   'date': '2024-12-13',
#   'open': 247.82,
#   'high': 249.29,
#   'low': 246.24,
#   'close': 248.13,
#   'volume': 33155300,
#   'change': 0.315,
#   'changePercent': 0.12509,
#   'vwap': 247.87},
#  {'symbol': 'AAPL',
#   'date': '2024-12-12',
#   'open': 246.89,
#   'high': 248.74,
#   'low': 245.68,
#   'close': 247.96,
#   'volume': 32777532,
#   'change': 1.07,
#   'changePercent': 0.43339,
#   'vwap': 247.3175},
#  {'symbol': 'AAPL',
#   'date': '2024-12-11',
#   'open': 247.96,
#   'high': 250.8,
#   'low': 246.26,
#   'close': 246.49,
#   'volume': 45205814,
#   'change': -1.47,
#   'changePercent': -0.59284,
#   'vwap': 247.8775},
#  {'symbol': 'AAPL',
#   'date': '2024-12-10',
#   'open': 246.89,
#   'high': 248.21,
#   'low': 245.34,
#   'close': 247.77,
#   'volume': 36914806,
#   'change': 0.88,
#   'changePercent': 0.35643,
#   'vwap': 247.0525},
#  {'symbol': 'AAPL',
#   'date': '2024-12-09',
#   'open': 241.83,
#   'high': 247.24,
#   'low': 241.75,
#   'close': 246.75,
#   'volume': 44649232,
#   'change': 4.92,
#   'changePercent': 2.03,
#   'vwap': 244.3925},
#  {'symbol': 'AAPL',
#   'date': '2024-12-06',
#   'open': 242.91,
#   'high': 244.63,
#   'low': 242.08,
#   'close': 242.84,
#   'volume': 36870619,
#   'change': -0.065,
#   'changePercent': -0.02881726,
#   'vwap': 243.115},
#  {'symbol': 'AAPL',
#   'date': '2024-12-05',
#   'open': 243.99,
#   'high': 244.54,
#   'low': 242.13,
#   'close': 243.04,
#   'volume': 40033900,
#   'change': -0.95,
#   'changePercent': -0.38936,
#   'vwap': 243.425},
#  {'symbol': 'AAPL',
#   'date': '2024-12-04',
#   'open': 242.87,
#   'high': 244.11,
#   'low': 241.25,
#   'close': 243.01,
#   'volume': 44383935,
#   'change': 0.14,
#   'changePercent': 0.05764401,
#   'vwap': 242.81},
#  {'symbol': 'AAPL',
#   'date': '2024-12-03',
#   'open': 239.81,
#   'high': 242.76,
#   'low': 238.9,
#   'close': 242.65,
#   'volume': 38861017,
#   'change': 2.84,
#   'changePercent': 1.18,
#   'vwap': 241.03},
#  {'symbol': 'AAPL',
#   'date': '2024-12-02',
#   'open': 237.27,
#   'high': 240.79,
#   'low': 237.16,
#   'close': 239.59,
#   'volume': 48137103,
#   'change': 2.32,
#   'changePercent': 0.97779,
#   'vwap': 238.7025},
#  {'symbol': 'AAPL',
#   'date': '2024-11-29',
#   'open': 234.81,
#   'high': 237.81,
#   'low': 233.97,
#   'close': 237.33,
#   'volume': 28481400,
#   'change': 2.53,
#   'changePercent': 1.07,
#   'vwap': 235.98},
#  {'symbol': 'AAPL',
#   'date': '2024-11-27',
#   'open': 234.47,
#   'high': 235.69,
#   'low': 233.81,
#   'close': 234.93,
#   'volume': 33498439,
#   'change': 0.465,
#   'changePercent': 0.19619,
#   'vwap': 234.725},
#  {'symbol': 'AAPL',
#   'date': '2024-11-26',
#   'open': 233.33,
#   'high': 235.57,
#   'low': 233.33,
#   'close': 235.06,
#   'volume': 45986200,
#   'change': 1.73,
#   'changePercent': 0.74144,
#   'vwap': 234.3225},
#  {'symbol': 'AAPL',
#   'date': '2024-11-25',
#   'open': 231.46,
#   'high': 233.25,
#   'low': 229.74,
#   'close': 232.87,
#   'volume': 90152832,
#   'change': 1.41,
#   'changePercent': 0.60918,
#   'vwap': 231.83},
#  {'symbol': 'AAPL',
#   'date': '2024-11-22',
#   'open': 228.06,
#   'high': 230.72,
#   'low': 228.06,
#   'close': 229.87,
#   'volume': 38168300,
#   'change': 1.81,
#   'changePercent': 0.79365,
#   'vwap': 229.1775},
#  {'symbol': 'AAPL',
#   'date': '2024-11-21',
#   'open': 228.88,
#   'high': 230.16,
#   'low': 225.71,
#   'close': 228.52,
#   'volume': 42108327,
#   'change': -0.36,
#   'changePercent': -0.15729,
#   'vwap': 228.3175},
#  {'symbol': 'AAPL',
#   'date': '2024-11-20',
#   'open': 228.06,
#   'high': 229.93,
#   'low': 225.89,
#   'close': 229,
#   'volume': 35169600,
#   'change': 0.94,
#   'changePercent': 0.41217,
#   'vwap': 228.22},
#  {'symbol': 'AAPL',
#   'date': '2024-11-19',
#   'open': 226.98,
#   'high': 230.16,
#   'low': 226.66,
#   'close': 228.28,
#   'volume': 36211800,
#   'change': 1.3,
#   'changePercent': 0.57274,
#   'vwap': 228.02},
#  {'symbol': 'AAPL',
#   'date': '2024-11-18',
#   'open': 225.25,
#   'high': 229.74,
#   'low': 225.17,
#   'close': 228.02,
#   'volume': 44686020,
#   'change': 2.77,
#   'changePercent': 1.23,
#   'vwap': 227.045},
#  {'symbol': 'AAPL',
#   'date': '2024-11-15',
#   'open': 226.4,
#   'high': 226.92,
#   'low': 224.27,
#   'close': 225,
#   'volume': 47923700,
#   'change': -1.4,
#   'changePercent': -0.61837,
#   'vwap': 225.6475},
#  {'symbol': 'AAPL',
#   'date': '2024-11-14',
#   'open': 225.02,
#   'high': 228.87,
#   'low': 225,
#   'close': 228.22,
#   'volume': 44923941,
#   'change': 3.2,
#   'changePercent': 1.42,
#   'vwap': 226.7775},
#  {'symbol': 'AAPL',
#   'date': '2024-11-13',
#   'open': 224.01,
#   'high': 226.65,
#   'low': 222.76,
#   'close': 225.12,
#   'volume': 48566217,
#   'change': 1.11,
#   'changePercent': 0.49551,
#   'vwap': 224.635},
#  {'symbol': 'AAPL',
#   'date': '2024-11-12',
#   'open': 224.55,
#   'high': 225.59,
#   'low': 223.36,
#   'close': 224.23,
#   'volume': 40398300,
#   'change': -0.32,
#   'changePercent': -0.14251,
#   'vwap': 224.4325},
#  {'symbol': 'AAPL',
#   'date': '2024-11-11',
#   'open': 225,
#   'high': 225.7,
#   'low': 221.5,
#   'close': 224.23,
#   'volume': 42005602,
#   'change': -0.77,
#   'changePercent': -0.34222,
#   'vwap': 224.1075},
#  {'symbol': 'AAPL',
#   'date': '2024-11-08',
#   'open': 227.17,
#   'high': 228.66,
#   'low': 226.41,
#   'close': 226.96,
#   'volume': 38328824,
#   'change': -0.21,
#   'changePercent': -0.09244178,
#   'vwap': 227.3},
#  {'symbol': 'AAPL',
#   'date': '2024-11-07',
#   'open': 224.63,
#   'high': 227.88,
#   'low': 224.57,
#   'close': 227.48,
#   'volume': 42137700,
#   'change': 2.85,
#   'changePercent': 1.27,
#   'vwap': 226.14},
#  {'symbol': 'AAPL',
#   'date': '2024-11-06',
#   'open': 222.61,
#   'high': 226.07,
#   'low': 221.19,
#   'close': 222.72,
#   'volume': 54561121,
#   'change': 0.11,
#   'changePercent': 0.04941377,
#   'vwap': 223.1475},
#  {'symbol': 'AAPL',
#   'date': '2024-11-05',
#   'open': 221.8,
#   'high': 223.95,
#   'low': 221.14,
#   'close': 223.45,
#   'volume': 28111338,
#   'change': 1.66,
#   'changePercent': 0.74391,
#   'vwap': 222.585},
#  {'symbol': 'AAPL',
#   'date': '2024-11-04',
#   'open': 220.99,
#   'high': 222.79,
#   'low': 219.71,
#   'close': 222.01,
#   'volume': 44944500,
#   'change': 1.02,
#   'changePercent': 0.46156,
#   'vwap': 221.375},
#  {'symbol': 'AAPL',
#   'date': '2024-11-01',
#   'open': 220.97,
#   'high': 225.35,
#   'low': 220.27,
#   'close': 222.91,
#   'volume': 65276741,
#   'change': 1.94,
#   'changePercent': 0.87795,
#   'vwap': 222.375},
#  {'symbol': 'AAPL',
#   'date': '2024-10-31',
#   'open': 229.34,
#   'high': 229.83,
#   'low': 225.37,
#   'close': 225.91,
#   'volume': 64370100,
#   'change': -3.43,
#   'changePercent': -1.5,
#   'vwap': 227.6125},
#  {'symbol': 'AAPL',
#   'date': '2024-10-30',
#   'open': 232.61,
#   'high': 233.47,
#   'low': 229.55,
#   'close': 230.1,
#   'volume': 47070907,
#   'change': -2.51,
#   'changePercent': -1.08,
#   'vwap': 231.4325},
#  {'symbol': 'AAPL',
#   'date': '2024-10-29',
#   'open': 233.1,
#   'high': 234.33,
#   'low': 232.32,
#   'close': 233.67,
#   'volume': 35417247,
#   'change': 0.57,
#   'changePercent': 0.24453,
#   'vwap': 233.355},
#  {'symbol': 'AAPL',
#   'date': '2024-10-28',
#   'open': 233.32,
#   'high': 234.73,
#   'low': 232.55,
#   'close': 233.4,
#   'volume': 36087134,
#   'change': 0.08,
#   'changePercent': 0.03428767,
#   'vwap': 233.5},
#  {'symbol': 'AAPL',
#   'date': '2024-10-25',
#   'open': 229.74,
#   'high': 233.22,
#   'low': 229.57,
#   'close': 231.41,
#   'volume': 38802304,
#   'change': 1.67,
#   'changePercent': 0.72691,
#   'vwap': 230.985},
#  {'symbol': 'AAPL',
#   'date': '2024-10-24',
#   'open': 229.98,
#   'high': 230.82,
#   'low': 228.41,
#   'close': 230.57,
#   'volume': 31109503,
#   'change': 0.59,
#   'changePercent': 0.25654,
#   'vwap': 229.945},
#  {'symbol': 'AAPL',
#   'date': '2024-10-23',
#   'open': 234.08,
#   'high': 235.14,
#   'low': 227.76,
#   'close': 230.76,
#   'volume': 52287000,
#   'change': -3.32,
#   'changePercent': -1.42,
# ...
#   'low': 169.51,
#   'close': 174.78,
#   'volume': 115541600,
#   'change': 4.62,
#   'changePercent': 2.72,
#   'vwap': 172.3625},
#  {'symbol': 'AAPL',
#   'date': '2022-01-28',
#   'open': 165.71,
#   'high': 170.35,
#   'low': 162.8,
#   'close': 170.33,
#   'volume': 179935700,
#   'change': 4.62,
#   'changePercent': 2.79,
#   'vwap': 167.2975},
#  {'symbol': 'AAPL',
#   'date': '2022-01-27',
#   'open': 162.45,
#   'high': 163.84,
#   'low': 158.28,
#   'close': 159.22,
#   'volume': 121954638,
#   'change': -3.23,
#   'changePercent': -1.99,
#   'vwap': 160.9475},
#  {'symbol': 'AAPL',
#   'date': '2022-01-26',
#   'open': 163.5,
#   'high': 164.39,
#   'low': 157.82,
#   'close': 159.69,
#   'volume': 108275308,
#   'change': -3.81,
#   'changePercent': -2.33,
#   'vwap': 161.35},
#  {'symbol': 'AAPL',
#   'date': '2022-01-25',
#   'open': 158.98,
#   'high': 162.76,
#   'low': 157.02,
#   'close': 159.78,
#   'volume': 115798400,
#   'change': 0.8,
#   'changePercent': 0.50321,
#   'vwap': 159.635},
#  {'symbol': 'AAPL',
#   'date': '2022-01-24',
#   'open': 160.02,
#   'high': 162.3,
#   'low': 154.7,
#   'close': 161.62,
#   'volume': 162706686,
#   'change': 1.6,
#   'changePercent': 0.99988,
#   'vwap': 159.66},
#  {'symbol': 'AAPL',
#   'date': '2022-01-21',
#   'open': 164.42,
#   'high': 166.33,
#   'low': 162.3,
#   'close': 162.41,
#   'volume': 122848900,
#   'change': -2,
#   'changePercent': -1.22,
#   'vwap': 163.865},
#  {'symbol': 'AAPL',
#   'date': '2022-01-20',
#   'open': 166.98,
#   'high': 169.68,
#   'low': 164.18,
#   'close': 164.51,
#   'volume': 91420515,
#   'change': -2.47,
#   'changePercent': -1.48,
#   'vwap': 166.3375},
#  {'symbol': 'AAPL',
#   'date': '2022-01-19',
#   'open': 170,
#   'high': 171.08,
#   'low': 165.94,
#   'close': 166.23,
#   'volume': 94815000,
#   'change': -3.77,
#   'changePercent': -2.22,
#   'vwap': 168.3125},
#  {'symbol': 'AAPL',
#   'date': '2022-01-18',
#   'open': 171.51,
#   'high': 172.54,
#   'low': 169.41,
#   'close': 169.8,
#   'volume': 91168729,
#   'change': -1.71,
#   'changePercent': -0.99703,
#   'vwap': 170.815},
#  {'symbol': 'AAPL',
#   'date': '2022-01-14',
#   'open': 171.34,
#   'high': 173.78,
#   'low': 171.09,
#   'close': 173.07,
#   'volume': 80440800,
#   'change': 1.73,
#   'changePercent': 1.01,
#   'vwap': 172.32},
#  {'symbol': 'AAPL',
#   'date': '2022-01-13',
#   'open': 175.78,
#   'high': 176.62,
#   'low': 171.79,
#   'close': 172.19,
#   'volume': 84505800,
#   'change': -3.59,
#   'changePercent': -2.04,
#   'vwap': 174.095},
#  {'symbol': 'AAPL',
#   'date': '2022-01-12',
#   'open': 176.12,
#   'high': 177.18,
#   'low': 174.82,
#   'close': 175.53,
#   'volume': 74805200,
#   'change': -0.59,
#   'changePercent': -0.335,
#   'vwap': 175.9125},
#  {'symbol': 'AAPL',
#   'date': '2022-01-11',
#   'open': 172.32,
#   'high': 175.18,
#   'low': 170.82,
#   'close': 175.08,
#   'volume': 76138312,
#   'change': 2.76,
#   'changePercent': 1.6,
#   'vwap': 173.35},
#  {'symbol': 'AAPL',
#   'date': '2022-01-10',
#   'open': 169.08,
#   'high': 172.5,
#   'low': 168.17,
#   'close': 172.19,
#   'volume': 106765600,
#   'change': 3.11,
#   'changePercent': 1.84,
#   'vwap': 170.485},
#  {'symbol': 'AAPL',
#   'date': '2022-01-07',
#   'open': 172.89,
#   'high': 174.14,
#   'low': 171.03,
#   'close': 172.17,
#   'volume': 86709147,
#   'change': -0.72,
#   'changePercent': -0.41645,
#   'vwap': 172.5575},
#  {'symbol': 'AAPL',
#   'date': '2022-01-06',
#   'open': 172.7,
#   'high': 175.3,
#   'low': 171.64,
#   'close': 172,
#   'volume': 96904000,
#   'change': -0.7,
#   'changePercent': -0.40533,
#   'vwap': 172.91},
#  {'symbol': 'AAPL',
#   'date': '2022-01-05',
#   'open': 179.61,
#   'high': 180.17,
#   'low': 174.64,
#   'close': 174.92,
#   'volume': 94537602,
#   'change': -4.69,
#   'changePercent': -2.61,
#   'vwap': 177.335},
#  {'symbol': 'AAPL',
#   'date': '2022-01-04',
#   'open': 182.63,
#   'high': 182.94,
#   'low': 179.12,
#   'close': 179.7,
#   'volume': 99310438,
#   'change': -2.93,
#   'changePercent': -1.6,
#   'vwap': 181.0975},
#  {'symbol': 'AAPL',
#   'date': '2022-01-03',
#   'open': 177.83,
#   'high': 182.88,
#   'low': 177.71,
#   'close': 182.01,
#   'volume': 104701220,
#   'change': 4.18,
#   'changePercent': 2.35,
#   'vwap': 180.1075},
#  {'symbol': 'AAPL',
#   'date': '2021-12-31',
#   'open': 178.09,
#   'high': 179.23,
#   'low': 177.26,
#   'close': 177.57,
#   'volume': 64062300,
#   'change': -0.515,
#   'changePercent': -0.29199,
#   'vwap': 178.0375},
#  {'symbol': 'AAPL',
#   'date': '2021-12-30',
#   'open': 179.47,
#   'high': 180.57,
#   'low': 178.09,
#   'close': 178.2,
#   'volume': 59773014,
#   'change': -1.27,
#   'changePercent': -0.70764,
#   'vwap': 179.0825},
#  {'symbol': 'AAPL',
#   'date': '2021-12-29',
#   'open': 179.33,
#   'high': 180.63,
#   'low': 178.14,
#   'close': 179.38,
#   'volume': 62348931,
#   'change': 0.05,
#   'changePercent': 0.02788156,
#   'vwap': 179.37},
#  {'symbol': 'AAPL',
#   'date': '2021-12-28',
#   'open': 180.16,
#   'high': 181.33,
#   'low': 178.53,
#   'close': 179.29,
#   'volume': 79144339,
#   'change': -0.87,
#   'changePercent': -0.4829,
#   'vwap': 179.8275},
#  {'symbol': 'AAPL',
#   'date': '2021-12-27',
#   'open': 177.09,
#   'high': 180.42,
#   'low': 177.07,
#   'close': 180.33,
#   'volume': 74919600,
#   'change': 3.25,
#   'changePercent': 1.83,
#   'vwap': 178.7275},
#  {'symbol': 'AAPL',
#   'date': '2021-12-23',
#   'open': 175.85,
#   'high': 176.85,
#   'low': 175.27,
#   'close': 176.28,
#   'volume': 68356600,
#   'change': 0.43,
#   'changePercent': 0.24453,
#   'vwap': 176.0625},
#  {'symbol': 'AAPL',
#   'date': '2021-12-22',
#   'open': 173.04,
#   'high': 175.86,
#   'low': 172.15,
#   'close': 175.64,
#   'volume': 92135303,
#   'change': 2.6,
#   'changePercent': 1.5,
#   'vwap': 174.1725},
#  {'symbol': 'AAPL',
#   'date': '2021-12-21',
#   'open': 171.56,
#   'high': 173.2,
#   'low': 169.12,
#   'close': 172.99,
#   'volume': 91185905,
#   'change': 1.44,
#   'changePercent': 0.83353,
#   'vwap': 171.7175},
#  {'symbol': 'AAPL',
#   'date': '2021-12-20',
#   'open': 168.28,
#   'high': 170.58,
#   'low': 167.46,
#   'close': 169.75,
#   'volume': 107499114,
#   'change': 1.47,
#   'changePercent': 0.87354,
#   'vwap': 169.0175},
#  {'symbol': 'AAPL',
#   'date': '2021-12-17',
#   'open': 169.93,
#   'high': 173.47,
#   'low': 169.69,
#   'close': 171.14,
#   'volume': 195923441,
#   'change': 1.21,
#   'changePercent': 0.71206,
#   'vwap': 171.0575},
#  {'symbol': 'AAPL',
#   'date': '2021-12-16',
#   'open': 179.28,
#   'high': 181.14,
#   'low': 170.75,
#   'close': 172.26,
#   'volume': 150185843,
#   'change': -7.02,
#   'changePercent': -3.92,
#   'vwap': 175.8575},
#  {'symbol': 'AAPL',
#   'date': '2021-12-15',
#   'open': 175.11,
#   'high': 179.5,
#   'low': 172.31,
#   'close': 179.3,
#   'volume': 131063300,
#   'change': 4.19,
#   'changePercent': 2.39,
#   'vwap': 176.555},
#  {'symbol': 'AAPL',
#   'date': '2021-12-14',
#   'open': 175.25,
#   'high': 177.74,
#   'low': 172.21,
#   'close': 174.33,
#   'volume': 139380400,
#   'change': -0.92,
#   'changePercent': -0.52496,
#   'vwap': 174.8825},
#  {'symbol': 'AAPL',
#   'date': '2021-12-13',
#   'open': 181.12,
#   'high': 182.13,
#   'low': 175.53,
#   'close': 175.74,
#   'volume': 153237019,
#   'change': -5.37,
#   'changePercent': -2.97,
#   'vwap': 178.63},
#  {'symbol': 'AAPL',
#   'date': '2021-12-10',
#   'open': 175.21,
#   'high': 179.63,
#   'low': 174.69,
#   'close': 179.45,
#   'volume': 115402731,
#   'change': 4.24,
#   'changePercent': 2.42,
#   'vwap': 177.245},
#  {'symbol': 'AAPL',
#   'date': '2021-12-09',
#   'open': 174.91,
#   'high': 176.75,
#   'low': 173.92,
#   'close': 174.56,
#   'volume': 108923739,
#   'change': -0.35,
#   'changePercent': -0.2001,
#   'vwap': 175.035},
#  {'symbol': 'AAPL',
#   'date': '2021-12-08',
#   'open': 172.13,
#   'high': 175.96,
#   'low': 170.7,
#   'close': 175.08,
#   'volume': 116998901,
#   'change': 2.96,
#   'changePercent': 1.71,
#   'vwap': 173.4675},
#  {'symbol': 'AAPL',
#   'date': '2021-12-07',
#   'open': 169.08,
#   'high': 171.58,
#   'low': 168.34,
#   'close': 171.18,
#   'volume': 120405400,
#   'change': 2.1,
#   'changePercent': 1.24,
#   'vwap': 170.045},
#  {'symbol': 'AAPL',
#   'date': '2021-12-06',
#   'open': 164.29,
#   'high': 167.88,
#   'low': 164.28,
#   'close': 165.32,
#   'volume': 107497000,
#   'change': 1.03,
#   'changePercent': 0.62694,
#   'vwap': 165.4425},
#  {'symbol': 'AAPL',
#   'date': '2021-12-03',
#   'open': 164.02,
#   'high': 164.96,
#   'low': 159.72,
#   'close': 161.84,
#   'volume': 118023116,
#   'change': -2.18,
#   'changePercent': -1.33,
#   'vwap': 162.635},
#  {'symbol': 'AAPL',
#   'date': '2021-12-02',
#   'open': 158.74,
#   'high': 164.2,
#   'low': 157.8,
#   'close': 163.76,
#   'volume': 136739200,
#   'change': 5.02,
#   'changePercent': 3.16,
#   'vwap': 161.125},
#  {'symbol': 'AAPL',
#   'date': '2021-12-01',
#   'open': 167.48,
#   'high': 170.3,
#   'low': 164.53,
#   'close': 164.77,
#   'volume': 152423003,
#   'change': -2.71,
#   'changePercent': -1.62,
#   'vwap': 166.77},
#  {'symbol': 'AAPL',
#   'date': '2021-11-30',
#   'open': 159.99,
#   'high': 165.52,
#   'low': 159.92,
#   'close': 165.3,
#   'volume': 174048100,
#   'change': 5.31,
#   'changePercent': 3.32,
#   'vwap': 162.6825},
#  {'symbol': 'AAPL',
#   'date': '2021-11-29',
#   'open': 159.37,
#   'high': 161.19,
#   'low': 158.79,
#   'close': 160.24,
#   'volume': 88748217,
#   'change': 0.87,
#   'changePercent': 0.5459,
#   'vwap': 159.8975},
#  {'symbol': 'AAPL',
#   'date': '2021-11-26',
#   'open': 159.57,
#   'high': 160.45,
#   'low': 156.36,
#   'close': 156.81,
#   'volume': 76959800,
#   'change': -2.75,
#   'changePercent': -1.73,
#   'vwap': 158.2975},
#  {'symbol': 'AAPL',
#   'date': '2021-11-24',
#   'open': 160.75,
#   'high': 162.14,
#   'low': 159.64,
#   'close': 161.94,
#   'volume': 69463623,
#   'change': 1.19,
#   'changePercent': 0.74028,
#   'vwap': 161.1175},
#  {'symbol': 'AAPL',
#   'date': '2021-11-23',
#   'open': 161.12,
#   'high': 161.8,
#   'low': 159.06,
#   'close': 161.41,
#   'volume': 96041900,
#   'change': 0.29,
#   'changePercent': 0.17999,
#   'vwap': 160.8475},
#  {'symbol': 'AAPL',
#   'date': '2021-11-22',
#   'open': 161.68,
#   'high': 165.7,
#   'low': 161,
#   'close': 161.02,
#   'volume': 117467900,
#   'change': -0.66,
#   'changePercent': -0.40821,
#   'vwap': 162.35},
#  {'symbol': 'AAPL',
#   'date': '2021-11-19',
#   'open': 157.65,
#   'high': 161.02,
#   'low': 156.53,
#   'close': 160.55,
#   'volume': 117305600,
#   'change': 2.9,
#   'changePercent': 1.84,
#   'vwap': 158.9375},
#  {'symbol': 'AAPL',
#   'date': '2021-11-18',
#   'open': 153.71,
#   'high': 158.67,
#   'low': 153.05,
#   'close': 157.87,
#   'volume': 137827700,
#   'change': 4.16,
#   'changePercent': 2.71,
#   'vwap': 155.825},
#  {'symbol': 'AAPL',
#   'date': '2021-11-17',
#   'open': 151,
#   'high': 155,
#   'low': 150.99,
#   'close': 153.49,
#   'volume': 88807000,
#   'change': 2.5,
#   'changePercent': 1.65,
#   'vwap': 152.62},
#  {'symbol': 'AAPL',
#   'date': '2021-11-16',
#   'open': 149.94,
#   'high': 151.49,
#   'low': 149.34,
#   'close': 151,
#   'volume': 59256210,
#   'change': 1.06,
#   'changePercent': 0.70695,
#   'vwap': 150.4425},
#  {'symbol': 'AAPL',
#   'date': '2021-11-15',
#   'open': 150.37,
#   'high': 151.88,
#   'low': 149.43,
#   'close': 150,
#   'volume': 59222803,
#   'change': -0.37,
#   'changePercent': -0.24606,
#   'vwap': 150.42},
#  {'symbol': 'AAPL',
#   'date': '2021-11-12',
#   'open': 148.43,
#   'high': 150.4,
#   'low': 147.48,
#   'close': 149.99,
#   'volume': 63804008,
#   'change': 1.56,
#   'changePercent': 1.05,
#   'vwap': 149.075},
#  {'symbol': 'AAPL',
#   'date': '2021-11-11',
#   'open': 148.96,
#   'high': 149.43,
#   'low': 147.68,
#   'close': 147.87,
#   'volume': 41000000,
#   'change': -1.09,
#   'changePercent': -0.73174,
#   'vwap': 148.485},
#  {'symbol': 'AAPL',
#   'date': '2021-11-10',
#   'open': 150.02,
#   'high': 150.13,
#   'low': 147.85,
#   'close': 147.92,
#   'volume': 65187100,
#   'change': -2.1,
#   'changePercent': -1.4,
#   'vwap': 148.98},
#  {'symbol': 'AAPL',
#   'date': '2021-11-09',
#   'open': 150.2,
#   'high': 151.43,
#   'low': 150.06,
#   'close': 150.81,
#   'volume': 56787930,
#   'change': 0.61,
#   'changePercent': 0.40613,
#   'vwap': 150.625},
#  {'symbol': 'AAPL',
#   'date': '2021-11-08',
#   'open': 151.41,
#   'high': 151.57,
#   'low': 150.16,
#   'close': 150.44,
#   'volume': 55020900,
#   'change': -0.97,
#   'changePercent': -0.64064,
#   'vwap': 150.895},
#  {'symbol': 'AAPL',
#   'date': '2021-11-05',
#   'open': 151.89,
#   'high': 152.2,
#   'low': 150.06,
#   'close': 151.28,
#   'volume': 65463900,
#   'change': -0.61,
#   'changePercent': -0.40161,
#   'vwap': 151.3575},
#  {'symbol': 'AAPL',
#   'date': '2021-11-04',
#   'open': 151.58,
#   'high': 152.43,
#   'low': 150.64,
#   'close': 150.96,
#   'volume': 60394616,
#   'change': -0.62,
#   'changePercent': -0.40902,
#   'vwap': 151.4025},
#  {'symbol': 'AAPL',
#   'date': '2021-11-03',
#   'open': 150.39,
#   'high': 151.97,
#   'low': 149.82,
#   'close': 151.49,
#   'volume': 54511534,
#   'change': 1.1,
#   'changePercent': 0.73143,
#   'vwap': 150.9175},
#  {'symbol': 'AAPL',
#   'date': '2021-11-02',
#   'open': 148.66,
#   'high': 151.57,
#   'low': 148.65,
#   'close': 150.02,
#   'volume': 69122000,
#   'change': 1.36,
#   'changePercent': 0.91484,
#   'vwap': 149.725},
#  {'symbol': 'AAPL',
#   'date': '2021-11-01',
#   'open': 148.99,
#   'high': 149.7,
#   'low': 147.8,
#   'close': 148.96,
#   'volume': 74588300,
#   'change': -0.025,
#   'changePercent': -0.02013558,
#   'vwap': 148.8625},
#  {'symbol': 'AAPL',
#   'date': '2021-10-29',
#   'open': 147.22,
#   'high': 149.94,
#   'low': 146.41,
#   'close': 149.8,
#   'volume': 124953200,
#   'change': 2.59,
#   'changePercent': 1.75,
#   'vwap': 148.3425},
#  {'symbol': 'AAPL',
#   'date': '2021-10-28',
#   'open': 149.82,
#   'high': 153.17,
#   'low': 149.72,
#   'close': 152.57,
#   'volume': 100077900,
#   'change': 2.75,
#   'changePercent': 1.84,
#   'vwap': 151.32},
#  {'symbol': 'AAPL',
#   'date': '2021-10-27',
#   'open': 149.36,
#   'high': 149.73,
#   'low': 148.49,
#   'close': 148.85,
#   'volume': 56094929,
#   'change': -0.51,
#   'changePercent': -0.34146,
#   'vwap': 149.1075},
#  {'symbol': 'AAPL',
#   'date': '2021-10-26',
#   'open': 149.33,
#   'high': 150.84,
#   'low': 149.01,
#   'close': 149.32,
#   'volume': 60893400,
#   'change': -0.01,
#   'changePercent': -0.00669658,
#   'vwap': 149.625},
#  {'symbol': 'AAPL',
#   'date': '2021-10-25',
#   'open': 148.68,
#   'high': 149.37,
#   'low': 147.62,
#   'close': 148.64,
#   'volume': 50720600,
#   'change': -0.04,
#   'changePercent': -0.02690342,
#   'vwap': 148.5775},
#  {'symbol': 'AAPL',
#   'date': '2021-10-22',
#   'open': 149.69,
#   'high': 150.18,
#   'low': 148.64,
#   'close': 148.69,
#   'volume': 58883443,
#   'change': -1,
#   'changePercent': -0.66805,
#   'vwap': 149.3},
#  {'symbol': 'AAPL',
#   'date': '2021-10-21',
#   'open': 148.81,
#   'high': 149.64,
#   'low': 147.87,
#   'close': 149.48,
#   'volume': 61421000,
#   'change': 0.67,
#   'changePercent': 0.45024,
#   'vwap': 148.95},
#  {'symbol': 'AAPL',
#   'date': '2021-10-20',
#   'open': 148.7,
#   'high': 149.75,
#   'low': 148.12,
#   'close': 149.26,
#   'volume': 58418800,
#   'change': 0.56,
#   'changePercent': 0.3766,
#   'vwap': 148.9575},
#  {'symbol': 'AAPL',
#   'date': '2021-10-19',
#   'open': 147.01,
#   'high': 149.17,
#   'low': 146.55,
#   'close': 148.76,
#   'volume': 76378900,
#   'change': 1.75,
#   'changePercent': 1.19,
#   'vwap': 147.8725},
#  {'symbol': 'AAPL',
#   'date': '2021-10-18',
#   'open': 143.45,
#   'high': 146.84,
#   'low': 143.16,
#   'close': 146.55,
#   'volume': 85589200,
#   'change': 3.11,
#   'changePercent': 2.16,
#   'vwap': 145},
#  {'symbol': 'AAPL',
#   'date': '2021-10-15',
#   'open': 143.77,
#   'high': 144.9,
#   'low': 143.51,
#   'close': 144.84,
#   'volume': 67940334,
#   'change': 1.07,
#   'changePercent': 0.74424,
#   'vwap': 144.255},
#  {'symbol': 'AAPL',
#   'date': '2021-10-14',
#   'open': 142.11,
#   'high': 143.88,
#   'low': 141.51,
#   'close': 143.76,
#   'volume': 69907100,
#   'change': 1.65,
#   'changePercent': 1.16,
#   'vwap': 142.815},
#  {'symbol': 'AAPL',
#   'date': '2021-10-13',
#   'open': 141.24,
#   'high': 141.4,
#   'low': 139.2,
#   'close': 140.91,
#   'volume': 78762721,
#   'change': -0.325,
#   'changePercent': -0.23364,
#   'vwap': 140.6875},
#  {'symbol': 'AAPL',
#   'date': '2021-10-12',
#   'open': 143.23,
#   'high': 143.25,
#   'low': 141.04,
#   'close': 141.51,
#   'volume': 73035900,
#   'change': -1.72,
#   'changePercent': -1.2,
#   'vwap': 142.2575},
#  {'symbol': 'AAPL',
#   'date': '2021-10-11',
#   'open': 142.27,
#   'high': 144.81,
#   'low': 141.81,
#   'close': 142.81,
#   'volume': 64452219,
#   'change': 0.54,
#   'changePercent': 0.37956,
#   'vwap': 142.925},
#  {'symbol': 'AAPL',
#   'date': '2021-10-08',
#   'open': 144.03,
#   'high': 144.18,
#   'low': 142.56,
#   'close': 142.9,
#   'volume': 58773200,
#   'change': -1.13,
#   'changePercent': -0.78456,
#   'vwap': 143.4175},
#  ...]

# %%
df_stock = pd.DataFrame(stock_data)
df_earnings = pd.DataFrame(earnings_data)

df_stock.head()
# Out:
#   symbol        date     open    high     low    close    volume  change  \
# 0   AAPL  2025-10-02  256.575  257.67  254.15  257.365  17488796   0.790
# 1   AAPL  2025-10-01  255.040  258.79  254.93  255.450  48713940   0.410
# 2   AAPL  2025-09-30  254.860  255.92  253.11  254.630  37704300  -0.225
# 3   AAPL  2025-09-29  254.560  255.00  253.01  254.430  40127700  -0.130
# 4   AAPL  2025-09-26  254.100  257.60  253.78  255.460  46076300   1.370
#
#    changePercent      vwap
# 0       0.307902  256.4000
# 1       0.160760  256.0525
# 2      -0.090246  254.6300
# 3      -0.051069  254.2500
# 4       0.535220  255.2350

# %%
df_stock_t = df_stock.T
df_earnings_t = df_earnings.T

# %%
df_stock_t
# Out:
#                      0           1           2           3           4     \
# symbol               AAPL        AAPL        AAPL        AAPL        AAPL
# date           2025-10-02  2025-10-01  2025-09-30  2025-09-29  2025-09-26
# open              256.575      255.04      254.86      254.56       254.1
# high               257.67      258.79      255.92       255.0       257.6
# low                254.15      254.93      253.11      253.01      253.78
# close             257.365      255.45      254.63      254.43      255.46
# volume           17488796    48713940    37704300    40127700    46076300
# change               0.79        0.41      -0.225       -0.13        1.37
# changePercent    0.307902     0.16076   -0.090246   -0.051069     0.53522
# vwap                256.4    256.0525      254.63      254.25     255.235
#
#                      5           6           7           8           9     \
# symbol               AAPL        AAPL        AAPL        AAPL        AAPL
# date           2025-09-25  2025-09-24  2025-09-23  2025-09-22  2025-09-19
# open               253.21      255.22      255.88       248.3      241.23
# high               257.17      255.74      257.34      256.64       246.3
# low                251.71      251.04      253.58      248.12      240.21
# close              256.87      252.31      254.43      256.08       245.5
# volume           55202100    42303710    60275200   105517416   163741314
# change               3.66       -2.91       -1.44        7.78        4.28
# changePercent        1.45       -1.14    -0.56667        3.13        1.77
# vwap               254.74    253.5775    255.3075     252.285      243.31
#
#                ...        1245        1246        1247        1248  \
# symbol         ...        AAPL        AAPL        AAPL        AAPL
# date           ...  2020-10-16  2020-10-15  2020-10-14  2020-10-13
# open           ...      121.28      118.72       121.0      125.27
# high           ...      121.55       121.2      123.03      125.39
# low            ...      118.81      118.15      119.62      119.65
# close          ...      119.02      120.71      121.19       121.1
# volume         ...   115393808   112559219   151062308   262330500
# change         ...       -2.26        1.99        0.19       -4.17
# changePercent  ...       -1.86        1.68     0.15702       -3.33
# vwap           ...     120.165     119.695      121.21    122.8525
#
#                      1249        1250        1251        1252        1253  \
# symbol               AAPL        AAPL        AAPL        AAPL        AAPL
# date           2020-10-12  2020-10-09  2020-10-08  2020-10-07  2020-10-06
# open               120.06      115.28      116.25      114.62       115.7
# high               125.18       117.0       116.4      115.55      116.12
# low                119.28      114.92      114.59      114.13      112.25
# close               124.4      116.97      114.97      115.08      113.16
# volume          240226800   100506900    83477200    96849000   161498212
# change               4.34        1.69       -1.28        0.46       -2.54
# changePercent        3.61        1.47        -1.1     0.40133        -2.2
# vwap               122.23    116.0425    115.5525     114.845    114.3075
#
#                      1254
# symbol               AAPL
# date           2020-10-05
# open               113.91
# high               116.65
# low                113.55
# close               116.5
# volume          106243839
# change               2.59
# changePercent        2.27
# vwap             115.1525
#
# [10 rows x 1255 columns]

# %%
df_earnings_t
# Out:
#                          0           1               2              3    \
# symbol                  AAPL        AAPL            AAPL           AAPL
# date              2026-04-26  2026-01-28      2025-10-30     2025-07-31
# epsActual                NaN         NaN             NaN           1.57
# epsEstimated             NaN         NaN            1.74           1.44
# revenueActual            NaN         NaN             NaN  94036000000.0
# revenueEstimated         NaN         NaN  101667067490.0  89562736363.0
# lastUpdated       2025-07-09  2025-10-02      2025-10-02     2025-10-02
#
#                             4               5              6              7    \
# symbol                     AAPL            AAPL           AAPL           AAPL
# date                 2025-05-01      2025-01-30     2024-10-31     2024-08-01
# epsActual                  1.65             2.4           1.64            1.4
# epsEstimated               1.63            2.36            1.6           1.35
# revenueActual     95359000000.0  124300000000.0  94930000000.0  85777000000.0
# revenueEstimated  94542181546.0  124257393152.0  94511953345.0  84432539529.0
# lastUpdated          2025-09-25      2025-09-25     2025-09-25     2025-09-25
#
#                             8               9    ...           153  \
# symbol                     AAPL            AAPL  ...          AAPL
# date                 2024-05-02      2024-02-01  ...    1987-12-31
# epsActual                  1.53            2.18  ...       0.00863
# epsEstimated                1.5             2.1  ...           NaN
# revenueActual     90753000000.0  119575000000.0  ...  1042400000.0
# revenueEstimated  90366105851.0  117986596460.0  ...           NaN
# lastUpdated          2025-09-25      2025-09-25  ...    2025-09-25
#
#                           154          155          156          157  \
# symbol                   AAPL         AAPL         AAPL         AAPL
# date               1987-09-30   1987-06-30   1987-03-31   1986-12-31
# epsActual             0.00508      0.00381      0.00242       0.0041
# epsEstimated              NaN          NaN          NaN          NaN
# revenueActual     786500000.0  637100000.0  575300000.0  662300000.0
# revenueEstimated          NaN          NaN          NaN          NaN
# lastUpdated        2025-09-25   2025-09-25   2025-09-25   2025-09-25
#
#                           158          159          160          161  \
# symbol                   AAPL         AAPL         AAPL         AAPL
# date               1986-09-30   1986-06-30   1986-03-31   1985-12-31
# epsActual             0.00235      0.00227      0.00227      0.00411
# epsEstimated              NaN          NaN          NaN          NaN
# revenueActual     510800000.0  448300000.0  408900000.0  533900000.0
# revenueEstimated          NaN          NaN          NaN          NaN
# lastUpdated        2025-09-25   2025-09-25   2025-09-25   2025-09-25
#
#                           162
# symbol                   AAPL
# date               1985-09-30
# epsActual             0.00161
# epsEstimated              NaN
# revenueActual     409700000.0
# revenueEstimated          NaN
# lastUpdated        2025-09-25
#
# [7 rows x 163 columns]

# %% [markdown]
# ## Define the past 4 quarters
# * Q3 2025, Q2 2025, Q1 2025, Q4 2024
# --> Extract daily stock price data from Sept 2024-Auf 2025

# %%
df_stock = df_stock[(df_stock["date"] >= "2024-09-01") & (df_stock["date"] <= "2025-08-31")]
df_stock
# Out:
#     symbol        date    open    high     low   close    volume  change  \
# 23    AAPL  2025-08-29  232.51  233.38  231.37  232.14  39418437  -0.370
# 24    AAPL  2025-08-28  230.82  233.41  229.34  232.56  38074700   1.740
# 25    AAPL  2025-08-27  228.61  230.90  228.26  230.49  31259513   1.880
# 26    AAPL  2025-08-26  226.87  229.49  224.69  229.31  54575107   2.440
# 27    AAPL  2025-08-25  226.48  229.30  226.23  227.16  30983133   0.680
# ..     ...         ...     ...     ...     ...     ...       ...     ...
# 267   AAPL  2024-09-09  220.82  221.27  216.71  220.91  67180000   0.090
# 268   AAPL  2024-09-06  223.95  225.24  219.77  220.82  48423011  -3.130
# 269   AAPL  2024-09-05  221.63  225.48  221.52  222.38  36615400   0.755
# 270   AAPL  2024-09-04  221.66  221.78  217.48  220.85  43840200  -0.810
# 271   AAPL  2024-09-03  228.55  229.00  221.17  222.77  50190600  -5.780
#
#      changePercent      vwap
# 23       -0.159130  232.3500
# 24        0.753830  231.5325
# 25        0.822360  229.5650
# 26        1.080000  227.5900
# 27        0.300250  227.2925
# ..             ...       ...
# 267       0.040757  219.9275
# 268      -1.400000  222.4450
# 269       0.338400  222.7525
# 270      -0.365420  220.4425
# 271      -2.530000  225.3725
#
# [249 rows x 10 columns]

# %% [markdown]
# * Merge the stock price data with the earnings data

# %%
df = pd.merge(
    left=df_stock,
    right=df_earnings,
    how="left",
    on="date"
)
df
# Out:
#     symbol_x        date    open    high     low   close    volume  change  \
# 0       AAPL  2025-08-29  232.51  233.38  231.37  232.14  39418437  -0.370
# 1       AAPL  2025-08-28  230.82  233.41  229.34  232.56  38074700   1.740
# 2       AAPL  2025-08-27  228.61  230.90  228.26  230.49  31259513   1.880
# 3       AAPL  2025-08-26  226.87  229.49  224.69  229.31  54575107   2.440
# 4       AAPL  2025-08-25  226.48  229.30  226.23  227.16  30983133   0.680
# ..       ...         ...     ...     ...     ...     ...       ...     ...
# 244     AAPL  2024-09-09  220.82  221.27  216.71  220.91  67180000   0.090
# 245     AAPL  2024-09-06  223.95  225.24  219.77  220.82  48423011  -3.130
# 246     AAPL  2024-09-05  221.63  225.48  221.52  222.38  36615400   0.755
# 247     AAPL  2024-09-04  221.66  221.78  217.48  220.85  43840200  -0.810
# 248     AAPL  2024-09-03  228.55  229.00  221.17  222.77  50190600  -5.780
#
#      changePercent      vwap symbol_y  epsActual  epsEstimated  revenueActual  \
# 0        -0.159130  232.3500      NaN        NaN           NaN            NaN
# 1         0.753830  231.5325      NaN        NaN           NaN            NaN
# 2         0.822360  229.5650      NaN        NaN           NaN            NaN
# 3         1.080000  227.5900      NaN        NaN           NaN            NaN
# 4         0.300250  227.2925      NaN        NaN           NaN            NaN
# ..             ...       ...      ...        ...           ...            ...
# 244       0.040757  219.9275      NaN        NaN           NaN            NaN
# 245      -1.400000  222.4450      NaN        NaN           NaN            NaN
# 246       0.338400  222.7525      NaN        NaN           NaN            NaN
# 247      -0.365420  220.4425      NaN        NaN           NaN            NaN
# 248      -2.530000  225.3725      NaN        NaN           NaN            NaN
#
#      revenueEstimated lastUpdated
# 0                 NaN         NaN
# 1                 NaN         NaN
# 2                 NaN         NaN
# 3                 NaN         NaN
# 4                 NaN         NaN
# ..                ...         ...
# 244               NaN         NaN
# 245               NaN         NaN
# 246               NaN         NaN
# 247               NaN         NaN
# 248               NaN         NaN
#
# [249 rows x 16 columns]

# %% [markdown]
# * Choosing a window of **3 days before and after** the event (the report about quarterly earnings)

# %%
# The event day for Q3 2025: 2025-07-31
Q3_2025 = df[(df["date"]>="2025-07-28") & (df["date"]<="2025-08-03")]

# The event day for Q2 2025: 2025-05-01
Q2_2025 = df[(df["date"]>="2025-04-28") & (df["date"]<="2025-05-04")]

# The event day for Q1 2025: 2025-01-30
Q1_2025 = df[(df["date"]>="2024-12-29") & (df["date"]<="2025-01-02")]

# The event day for Q4 2024: 2024-10-31
Q4_2025 = df[(df["date"]>="2024-10-28") & (df["date"]<="2024-11-02")]

# %%
Q3_2025.T.head()
# Out:
#                   20          21          22          23          24
# symbol_x        AAPL        AAPL        AAPL        AAPL        AAPL
# date      2025-08-01  2025-07-31  2025-07-30  2025-07-29  2025-07-28
# open          210.87      208.49       211.9      214.18      214.03
# high          213.58      209.84      212.39      214.81      214.85
# low            201.5      207.16      207.72      210.82      213.06

# %%
Q2_2025.T.head()
# Out:
#                   82          83          84          85          86
# symbol_x        AAPL        AAPL        AAPL        AAPL        AAPL
# date      2025-05-02  2025-05-01  2025-04-30  2025-04-29  2025-04-28
# open          206.09      209.08       209.3      208.69       210.0
# high          206.99      214.56      213.58      212.24       211.5
# low           202.16       208.9      206.67      208.37      207.46

# %%
Q1_2025.T.head()
# Out:
#                  164         165         166
# symbol_x        AAPL        AAPL        AAPL
# date      2025-01-02  2024-12-31  2024-12-30
# open          248.93      252.44      252.23
# high           249.1      253.28       253.5
# low           241.82      249.43      250.75

# %%
Q4_2025.T.head()
# Out:
#                  205         206         207         208         209
# symbol_x        AAPL        AAPL        AAPL        AAPL        AAPL
# date      2024-11-01  2024-10-31  2024-10-30  2024-10-29  2024-10-28
# open          220.97      229.34      232.61       233.1      233.32
# high          225.35      229.83      233.47      234.33      234.73
# low           220.27      225.37      229.55      232.32      232.55

# %% [markdown]
# A 3-day window for certain quarters is lacking because the market is closed on holidays or weekends --> missing stock data on those days. So if that day is missing, window should jump to the next nerest trading dates --> **Trading-Day indexing**

# %%
def get_event_window(df, event_day, window =3):
    df = df.sort_values("date").reset_index(drop=True) # avoid having t-3 as a future date, as the FMP returns stock data in descending order
    df["date"] = pd.to_datetime(df["date"])
    event_day  = pd.to_datetime(event_day)

    # If event day is not in trading date, move forward to the next trading day
    if event_day not in df["date"].values:
        event_day = df[df["date"] > event_day]["date"].iloc[0]

    idx = df.index[df["date"]== event_day][0] # [0] grabs the first element of that index list (the index list: Int64Index([***], dtype='int64'))
    return df.iloc[idx-window: idx+window+1]

# %%
Q3_2025 = get_event_window(df, "2025-07-31", 3)
Q2_2025 = get_event_window(df, "2025-05-01", 3)
Q1_2025 = get_event_window(df, "2025-01-30", 3)
Q4_2024 = get_event_window(df, "2024-10-31", 3)

# %%
Q1_2025.head()
# Out:
#     symbol_x       date    open    high     low   close     volume  change  \
# 99      AAPL 2025-01-27  224.02  232.15  223.98  229.86   94863418    5.84
# 100     AAPL 2025-01-28  230.85  240.19  230.81  238.26   75707600    7.41
# 101     AAPL 2025-01-29  234.12  239.86  234.01  239.36   45486100    5.24
# 102     AAPL 2025-01-30  238.67  240.79  237.21  237.59   55658300   -1.07
# 103     AAPL 2025-01-31  247.19  247.19  233.44  236.00  101075128  -11.19
#
#      changePercent      vwap symbol_y  epsActual  epsEstimated  revenueActual  \
# 99         2.61000  227.5025      NaN        NaN           NaN            NaN
# 100        3.21000  235.0275      NaN        NaN           NaN            NaN
# 101        2.24000  236.8375      NaN        NaN           NaN            NaN
# 102       -0.45251  238.5650     AAPL        2.4          2.36   1.243000e+11
# 103       -4.53000  240.9550      NaN        NaN           NaN            NaN
#
#      revenueEstimated lastUpdated
# 99                NaN         NaN
# 100               NaN         NaN
# 101               NaN         NaN
# 102      1.242574e+11  2025-09-25
# 103               NaN         NaN

# %% [markdown]
# ## Define the north star metrics
# 1> Immediate retunr (t-1 to t+1) --> capture the impact of the earning itself on the market
# 2> Extended drift return (t-3 to t+3) --> check the trending of the initial reaction
# 3> Gap return (overnight reaction) --> capture the difference between event day 's open and previous day 's close

# %%
def calculate_metrics(event_df):
    """
    event_df: DataFrame with 7 rows (t-3 ... t+3) for a quarter
    Assumes columns: 'date', 'open', 'close'
    """
    # t-3 and t+3
    t_minus3_close = event_df.iloc[0]['close']
    t_plus3_close = event_df.iloc[-1]['close']
    
    # t-1, t0, t+1
    t_minus1_close = event_df.iloc[3-1]['close']  # 4th row is t0, so t-1 is 3rd row
    t0_open = event_df.iloc[3]['open']
    t_plus1_close = event_df.iloc[3+1]['close']
    
    # Metrics
    immediate_return = (t_plus1_close - t_minus1_close) / t_minus1_close * 100
    extended_drift = (t_plus3_close - t_minus3_close) / t_minus3_close * 100
    gap_return = (t0_open - t_minus1_close) / t_minus1_close * 100
    
    return {
        'Immediate Return %': round(immediate_return, 2),
        'Extended Drift %': round(extended_drift, 2),
        'Gap Return %': round(gap_return, 2)
    }

# Apply to all quarters
metrics_Q4_2024 = calculate_metrics(Q4_2024)
metrics_Q1_2025 = calculate_metrics(Q1_2025)
metrics_Q2_2025 = calculate_metrics(Q2_2025)
metrics_Q3_2025 = calculate_metrics(Q3_2025)

# Combine into one DataFrame
df_metrics = pd.DataFrame([
    {'Quarter': 'Q4 2024', **metrics_Q4_2024},
    {'Quarter': 'Q1 2025', **metrics_Q1_2025},
    {'Quarter': 'Q2 2025', **metrics_Q2_2025},
    {'Quarter': 'Q3 2025', **metrics_Q3_2025},
])

print(df_metrics)
# Out:
#    Quarter  Immediate Return %  Extended Drift %  Gap Return %
# 0  Q4 2024               -3.12             -4.26         -0.33
# 1  Q1 2025               -1.40              1.28         -0.29
# 2  Q2 2025               -3.36             -5.53         -1.61
# 3  Q3 2025               -3.19             -5.20         -0.27

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

event_dates = ["2024-10-31", "2025-01-30", "2025-05-01", "2025-07-31"]
event_dates_dt = pd.to_datetime(event_dates)
df_stock['date'] = pd.to_datetime(df_stock['date'])
event_dates_dt = pd.to_datetime(event_dates)

plt.figure(figsize=(12,6))
plt.plot(df_stock['date'], df_stock['close'], label='AAPL Close', color='blue')

# Add vertical markers for each earnings event
for d in event_dates_dt:
    plt.axvline(d, color='red', linestyle='--', alpha=0.7)
    plt.text(d+pd.Timedelta(days=1), df_stock['close'].max()*1.005, d.strftime('%Y-%m-%d'), color='red', fontsize=9) # Text is slightly to the right (+1 day); text is slightly above the max price 


plt.title('Apple Stock Price with Quarterly Earnings Event Markers')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.tight_layout()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(len(df_metrics['Quarter']))  # label locations
width = 0.25  # bar width

plt.figure(figsize=(10,6))
plt.bar(x - width, df_metrics['Immediate Return %'], width, label='Immediate Return', color='#C0C0C0')  # Silver
plt.bar(x, df_metrics['Extended Drift %'], width, label='Extended Drift', color='#4B4B4B')  # Dark Gray
plt.bar(x + width, df_metrics['Gap Return %'], width, label='Gap Return', color='#5AC8FA')  # Apple Blue / Teal

plt.xticks(x, df_metrics['Quarter'])
plt.ylabel('Return (%)')
plt.title('Apple Stock Performance Around Earnings Across Quarters')
plt.legend()
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()
